# %% [markdown]
# # Purpose.
# This notebook allows me to works through the different aspects of webscrapping using the requests library and parsing through that information using Beautiful Soup 4 in order to collect information on plants native to my region. The next phase of this project is to use SQLite to upload that data into a database.
#
# Version 1 used wildflower.org in order to find the name of plants native to Virginia that are comercially available. Those names were then used to scrape Wikipedia for limited information. Wildflower.org was a little too inconsistent for me to build a routine to webscrape.
#
# Version 2 looks at https://www.nativeplantcenter.net/ by first going through the search results for plants native to my specific region of the Chesapeake Bay and storing the hyperlinks used to access more information about the plants. Those links are then used to get all the information the website displays about the plants which is stored as a list of lists, with each index representing a different plant.

# %%
import requests
import bs4

# %%
# Go through the search results for plants native to my region and grab the links to websites specifc to those plants
# npc stands for native plant center, the name of the website
npc_links = []
for i in range(27):
    url = 'https://www.nativeplantcenter.net/plants/page/'+str(i+1)+'/?s&regions%5B0%5D=coastal-plain#038;regions%5B0%5D=coastal-plain'
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,"lxml")
    
    # get the links attached to the search results
    hrefs = soup.select('body')[0].find_all('div',class_="row plants-images")[0].find_all("a", href=True)
    for link in hrefs:
        npc_links.append(link['href'])

# %%
# We will create a dictionary of all the information found on the links. This does two things
# 1) Organize the data how we see fit
# 2) Circumvent problems that arrise from inconsistent information categories. Some plants include a section about
#    "Ground Cover" while also omitting "Flower color" because those plants don't flower.

# The following is a constant based on all possible sections of information.

CATEGORIES = ['Binomial','Common Names','Family','Regions','States','Plant Types','Height','Flower Color','Fruit',
              'Sun Exposure', 'Soil Texture','Soil Moisture','Blooms','Fall Color','Ground Cover','Habitat','Notes']

# %%
plant_info = []


for url in npc_links:
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,"lxml")
    
    #binomial name
    binomial_name = soup.find('body').find_all('h1')[1].get_text()
    
    #common names
    common_names = soup.find('body').select('strong')[0].get_text()
    
    #all the other info
    body_info = soup.find('body').find('div', class_ = 'row nomarginrow').select('p')
    cleaned_body_info = []
    for entry in body_info:
        if len(entry.get_text()) > 0:
            cleaned_body_info.append(entry.get_text())
    
    #create a dictionary of all the information
    plant_dict = {"Binomial" : binomial_name, "Common Names" : common_names}
    for i, entry in enumerate(cleaned_body_info):
        try:
            titles = cleaned_body_info[i][:cleaned_body_info[i].index(':')]    
            info = cleaned_body_info[i][cleaned_body_info[i].index(':')+2:]
            plant_dict.update({titles:info})
        except:
            #sometimes sections of the information we want is empty, this filters them out
            pass
        
    # List of the information we want in the order we want
    info_list = []
    for i,entry in enumerate(CATEGORIES):
        try:
            info_list.append(plant_dict[entry])
        except:
            info_list.append('NA')
        

    #now putting it all in the list we want
    plant_info.extend([info_list])

# %%
# Data validation
# The length of plant_info should be 319. There are 12 results for each of he 26 pages and 7 on the last page.

len(plant_info)

# %%
# Append the categories to the beginning of the plant_info list in order to know what all the indices mean
plant_info.insert(0, CATEGORIES)
# Out:
# [['Binomial',
#   'Common Names',
#   'Family',
#   'Regions',
#   'States',
#   'Plant Types',
#   'Height',
#   'Flower Color',
#   'Fruit',
#   'Sun Exposure',
#   'Soil Texture',
#   'Soil Moisture',
#   'Blooms',
#   'Fall Color',
#   'Ground Cover',
#   'Habitat',
#   'Notes'],
#  ['Binomial',
#   'Common Names',
#   'Family',
#   'Regions',
#   'States',
#   'Plant Types',
#   'Height',
#   'Flower Color',
#   'Fruit',
#   'Sun Exposure',
#   'Soil Texture',
#   'Soil Moisture',
#   'Blooms',
#   'Fall Color',
#   'Ground Cover',
#   'Habitat',
#   'Notes'],
#  ['Acer negundo',
#   ' box elder, ash leaf maple, Manitoba maple',
#   'Aceraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '30 - 60ft; Spread: 30 - 60ft',
#   'yellow-green',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow, red',
#   'NA',
#   'grows best in lowland sites along rivers, streams, ponds, and seasonally flooded areas; tolerates a variety of soil types',
#   'brittle wood; thicket-forming'],
#  ['Acer rubrum',
#   ' red maple, scarlet maple, swamp maple, soft maple',
#   'Aceraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '40 - 100ft; Spread: 30 - 75ft',
#   '(inconspicuous)',
#   'Winged;          red-brown or yellow',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'red, orange, yellow',
#   'NA',
#   'swamps, uplands;  occasionally on dry rocky hillsides and sanddunes',
#   'earliest spring bloomer; adaptable'],
#  ['Actaea pachypoda',
#   " doll's eyes",
#   'Ranunculaceae',
#   'Coastal Plain',
#   'DE, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'whitish',
#   'Berry;          white or red',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'rich open woods, thickets',
#   'interesting berries; infrequent in Piedmont and mountain regions'],
#  ['Adiantum pedatum',
#   ' northern maidenhair fern',
#   'Pteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Fern',
#   '1 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'rich, moist woods; rocky well-shaded habitats, protected from dryness or direct sunlight',
#   'grows in clumps; delicate texture; herbal uses'],
#  ['Agalinis purpurea',
#   ' purple false foxglove',
#   'Scrophulariaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '1 - 4ft; ',
#   'rose-purple, white',
#   'Capsule;         ',
#   'Full Sun',
#   'Sandy',
#   'Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'moist sandy fields, rocky shores, serpentine barrens',
#   'NA'],
#  ['Ageratina altissima var. altissima',
#   ' white snakeroot',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'rich woods, thickets, clearings, meadows',
#   'tough plant; cultivars available; prefers basic soils'],
#  ['Agrostis perennans',
#   ' autumn bentgrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, PA, VA, WV',
#   'Grass/Grasslike',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'dry or moist thickets, open woods, unshaded areas',
#   'NA'],
#  ['Alnus serrulata',
#   ' smooth alder, hazel alder',
#   'Betulaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Shrub',
#   '12 - 20ft; Spread: 12 - 20ft',
#   'purple',
#   'Cone/Cone-like;          brown',
#   'Full Sun',
#   'Clay, Loamy',
#   'Flooded, Moist, Wet',
#   'March -          April',
#   'yellow, red',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands',
#   'forms thickets along watercourses; nitrogen fixing; tolerates flooding to 3"'],
#  ['Amelanchier canadensis',
#   ' serviceberry, shadbush, shadblow serviceberry, Canadian serviceberry',
#   'Rosaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA',
#   'Small/Medium Tree (Understory)',
#   '35 - 50ft; Spread: 35 - 50ft',
#   'white',
#   'Fleshy;          red to purple',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'orange to red',
#   'NA',
#   'swamps, low ground, woods, & thickets',
#   'NA'],
#  ['Ammophila breviligulata',
#   ' dunegrass, American beachgrass',
#   'Poaceae',
#   'Coastal Plain',
#   'VA',
#   'Grass/Grasslike',
#   '1.5 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'maritime beach/dunes, maritime grassland, maritime shrubland',
#   'prefers well-drained, sandy sites; spreads rapidly by rhizomes'],
#  ['Andropogon glomeratus',
#   ' bushy bluestem',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1.5 - 5ft; ',
#   'reddish brown',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'August -          October',
#   'reddish',
#   'NA',
#   'fresh marshes, wet soils, coastal areas',
#   'tolerates drought; grows in tufts; reddish fall color'],
#  ['Andropogon virginicus',
#   ' broomsedge',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3ft; ',
#   'reddish brown',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'August -          November',
#   'reddish-tan',
#   'NA',
#   'wet meadows, transition areas; poor soils',
#   'wildlife food and cover; tolerates drought; grows in tufts; reddish-tan fall color'],
#  ['Aquilegia canadensis',
#   ' eastern or wild columbine',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 3ft; ',
#   'red-yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'rich rocky woods and slopes, cliffs, ledges, pastures, and roadside banks; rarely in swamps',
#   'commonly cultivated; spreads by seed'],
#  ['Aralia nudicaulis',
#   ' wild sarsaparilla',
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'white or green',
#   'Berry;          purple-black',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'NA',
#   'dry to moist woods',
#   'aromatic; single-leaved; lacks an above-ground stem; not common in coastal plain'],
#  ['Aralia racemosa',
#   ' spikenard',
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'greenish-white',
#   'Berry;          dark purple',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'rich woods and thickets, wooded slopes and edges',
#   'not common in coastal plain'],
#  ['Aralia spinosa',
#   " Devil's walking stick",
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Tall Shrub',
#   '20 - 30ft; Spread: 12 - 20ft',
#   'white',
#   'Berry;          black',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          August',
#   'yellow',
#   'NA',
#   'moist woods, stream banks, roadsides',
#   'seeds are poisonous if chewed; low maintenance; spreads from new shoots; thorny, clublike stem'],
#  ['Arisaema triphyllum',
#   ' Jack-in-the-pulpit',
#   'Araceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'striped, purple or green',
#   'Berry;         ',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'March -          June',
#   'NA',
#   'NA',
#   'wet woods, bogs and swamps',
#   'red berry clusters appear late summer to fall; unusual flower; spreads rapidly from seed'],
#  ['Asarum canadense',
#   ' wild ginger',
#   'Aristolochiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'brownish-purple',
#   'Capsule;          brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'semi-evergreen',
#   'Yes',
#   'rich woodlands, less so on acid soils',
#   'flower inconspicuous; attractive leaves; will spread; semi-evergreen'],
#  ['Asclepias incarnata',
#   ' swamp milkweed',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '4 - 6ft; ',
#   'pink to reddish',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'May -          June',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, wet meadows, shrub swamps, clearings of wet woods, shores and ditches',
#   'can tolerate drought; interesting seed pod'],
#  ['Asclepias syriaca',
#   ' common milkweed',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '3.5 - 6.5ft; ',
#   'pale purple',
#   'Pod;         ',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'May -          August',
#   'NA',
#   'NA',
#   'thickets, roadsides, dry fields',
#   'interesting seed pods; fragrant flower'],
#  ['Asclepias tuberosa',
#   ' butterflyweed, butterfly milkweed, butterfly flower',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'orange',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'NA',
#   'dry fields, roadsides and shale barrens',
#   'taproot does not transplant well but seedlings do; attractive seed pod'],
#  ['Asimina triloba',
#   ' paw-paw',
#   'Annonaceae',
#   'Coastal Plain',
#   'DE, DC, MD, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'purple',
#   'Berry;          yellow',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'April -          June',
#   'yellow/copper-red',
#   'NA',
#   'deep, rich, moist soils of river valleys and bottomlands.  Also in the understory of hardwood forests.',
#   'NA'],
#  ['Asplenium platyneuron',
#   ' ebony spleenwort',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, VA, WV',
#   'Fern',
#   '0.5 - 1.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'NA',
#   'evergreen',
#   'Yes',
#   'sandy or clayey banks, open woods and thickets, slopes, rocky ledges, swamps',
#   'easily transplanted; only moderate care needed; evergreen'],
#  ['Athyrium filix-femina',
#   ' northern lady fern',
#   'Dryopteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Partial Sun',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'wet woods, moist banks, wooded hillsides, sandy bogs',
#   'varieties occur throughout region; in MD, VA can also use subspecies asplenioides (southern lady fern)'],
#  ['Baccharis halimifolia',
#   ' high-tide bush, groundsel tree, sea myrtle',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, MD, VA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white',
#   'Achene (dry, flat seed);          silvery white',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'August -          September',
#   'purple',
#   'NA',
#   'salt or brackish marshes, fresh tidal marshes and ditches, shores, dunes',
#   'volunteers in disturbed places; shallow, lateral roots; tolerates flooding to 6"; tolerates salinity to 15 ppt'],
#  ['Baptisia tinctoria',
#   ' yellow wild indigo',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'May -          September',
#   'NA',
#   'NA',
#   'dry open woods and clearings, sandy acidic soil',
#   'tolerates poor soils'],
#  ['Betula nigra',
#   ' river birch, red birch, black birch',
#   'Betulaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'dark brown',
#   'Cone/Cone-like;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'lowland species mainly along streams, rivers, ponds, and swamps',
#   'attractive peeling bark;'],
#  ['Bidens cernua',
#   ' nodding beggar-ticks, nodding bur marigold',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '0.5 - 3ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'tidal marsh, sloughs, springs, pools, shore',
#   'NA'],
#  ['Bignonia capreolata',
#   ' crossvine',
#   'Bignoniaceae',
#   'Coastal Plain',
#   'MD, VA',
#   'Vine',
#   '30 - 45ft; Spread: 20 - 35ft',
#   'orange with red',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'semi-evergreen; reddish-purple',
#   'Yes',
#   'alluvial woods, swampy forests, calcareous soils on river banks, cliffs in ravines, dry open woods, bogs, fence rows, rock outcrops',
#   'spreads across ground and climbs any structure it meets (control by cutting); semi-evergreen'],
#  ['Boltonia asteroides',
#   " star boltonia, white doll's daisy",
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, VA, WV',
#   'Herbaceous',
#   '0.5 - 2.5ft; ',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'gravelly shores, sandy thickets',
#   'NA'],
#  ['Botrychium virginianum',
#   ' rattlesnake fern',
#   'Ophioglossaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'rich, well-drained, wooded areas',
#   'NA'],
#  ['Callicarpa americana',
#   ' American beautyberry, French mulberry',
#   'Verbenaceae',
#   'Coastal Plain',
#   'DC, VA',
#   'Medium Shrub',
#   '6 - 6ft; Spread: 6 - 6ft',
#   'lavender-pink',
#   'Berry;          lavender',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'in most soils',
#   'flowers from new growth; if overgrown prune to 6-18" tall; will regain height in one season'],
#  ['Caltha palustris',
#   ' marsh marigold',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '1 - 2ft; ',
#   'bright yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Flooded, Wet',
#   'April -          June',
#   'NA',
#   'NA',
#   'forested wetlands, shrub swamps, streambanks, seeps, wet meadows',
#   'clump-forming; needs some periods of drier soil; tolerates flooding to 6"'],
#  ['Campsis radicans',
#   ' trumpet vine, trumpet creeper',
#   'Bignoniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA',
#   'Vine',
#   '30 - 30ft; Spread: 20 - 35ft',
#   'orange',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'yellow green',
#   'Yes',
#   'moist woodlands, fence rows, roadside thickets, floodplain forests, rock hillsides, open woods, stream banks, old fields',
#   'thick, twisted, aged woody vines; leaves/flowers may cause dermatitis (skin irritation)'],
#  ['Carex crinita var. crinita',
#   ' long hair sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'swales, damp thickets, and low woods',
#   'NA'],
#  ['Carex glaucodea',
#   ' blue wood sedge',
#   'Cyperaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Grass/Grasslike',
#   '0.5 - 2ft; ',
#   'brown to reddish',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'Yes',
#   'moist to dry woods and fields',
#   'clump-forming; alternative to Liriope'],
#  ['Carex lurida',
#   ' sallow sedge, lurid sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'swales, swamps, and wet woods',
#   'wetland plant; interesting seeds'],
#  ['Carex pensylvanica',
#   ' Pennsylvania sedge',
#   'Cyperaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 1.5ft; ',
#   'reddish to white',
#   'NA',
#   'Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'open dry soil or open woods; dry or sandy, open or rocky oak woods, wooded slopes; clump-forming',
#   'alternative to lawn; plant densely; fine textured leaves <6"'],
#  ['Carex stricta',
#   ' tussock sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'reddish to purple brown',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'May -          August',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands, wet swales, moist fields',
#   'grows in clumps; partly persists in winter; tolerates flooding to 6"'],
#  ['Carex vulpinoidea',
#   ' fox sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '0.5 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Flooded, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'shallow emergent marsh, shrub swamp, floodplain forest, hardwood swamp',
#   'grows in clumps; tolerates saturation and flooding to 6"'],
#  ['Carya alba',
#   ' mockernut hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 35 - 50ft',
#   'light green',
#   'Nut/Nut-like;          light reddish brown',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'NA',
#   'ridges, dry hills, and hillsides; rich well drained soils',
#   'good fall color'],
#  ['Carya cordiformis',
#   ' bitternut hickory, swamp hickory, pignut, bitternut',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 60 - 100ft',
#   'yellow-green',
#   'Nut/Nut-like;          yellowish green',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'can grow in swamps and frequently flooded areas and dry hillsides; does best in rich bottomlands',
#   'NA'],
#  ['Carya glabra',
#   ' pignut hickory, sweet pignut hickory, smooth bark hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 35 - 50ft',
#   'yellow-green',
#   'Nut/Nut-like;          dark brown',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'dry woods, primarily on hillsides and along dry ridges; does best in deep, moist, well drained soils',
#   'NA'],
#  ['Carya ovata',
#   ' shagbark hickory, scalybark hickory, shellbark hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '70 - 100ft; Spread: 35 - 50ft',
#   'yellow-green',
#   'Nut/Nut-like;          dark or reddish brown',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'May -          June',
#   'brown',
#   'NA',
#   'both dry upland slopes to 2,000 feet, and deep well-drained soils in lowlands and valleys',
#   'attractive peeling bark'],
#  ['Castanea pumila',
#   ' chinquapin, chinkapin, eastern chinkapin, Allegany chinkapin',
#   'Fagaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '12 - 20ft; Spread: 12 - 20ft',
#   'pale yellow',
#   'Nut/Nut-like;          dark brown',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'June -          June',
#   'yellow or purple',
#   'NA',
#   'dry rocky slopes, dry woods, steep rocky land, rocky stream banks, sandy ridges, borders of swamps, open woods',
#   'sweet, edible fruit'],
#  ['Caulophyllum thalictroides',
#   ' blue cohosh',
#   'Berberidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'green-yellow, green-purple',
#   'Berry;          dark blue',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'moist rich woods',
#   'NA'],
#  ['Ceanothus americanus',
#   ' New Jersey tea',
#   'Rhamnaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 3ft; Spread: 3 - 6ft',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry',
#   'May -          September',
#   'yellow to tan',
#   'NA',
#   'meadow, old field, glade, forest; dry open woods and borders, rocky areas, openings',
#   'tough; tolerates moist soil if well drained; fixes nitrogen; tolerates dryness'],
#  ['Celastrus scandens',
#   ' American bittersweet',
#   'Celastraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Vine',
#   '3 - 35ft; Spread: 6 - 20ft',
#   'greenish',
#   'Capsule;          orange and red',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'Yes',
#   'roadsides, woods edge, fence rows, old pastures, hedges, rocky streams, bluffs, rocky slopes, dunes, sandy oak woods',
#   'distinguished from nonnative invasive Oriental bittersweet by flowers/fruits in clusters at ends of twigs'],
#  ['Celtis occidentalis',
#   ' common hackberry, sugarberry, nettletree',
#   'Ulmaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '40 - 100ft; Spread: 40 - 100ft',
#   'yellow green, brown tint',
#   'Berry;          purple brown',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'drainage basins, mature floodplains, wooded slopes or high rocky limestone bluffs bordering streams, windbreaks',
#   'butterfly larval host; drought tolerant; tolerates occasional flooding; saplings can sprout in deep shade, common on limestone soils'],
#  ['Cephalanthus occidentalis',
#   ' buttonbush',
#   'Rubiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 12 - 20ft',
#   'creamy white',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'July -          August',
#   'yellow-green',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands, borders of streams, lakes, and ponds',
#   'needs sun to flower; flowers fragrant; interesting fruit; tolerates drought; leaves may persist into winter; tolerates flooding to 36"'],
#  ['Cercis canadensis',
#   ' eastern redbud',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'pink to lavender',
#   'Pod;          black',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          May',
#   'golden yellow',
#   'NA',
#   'rich, moist sites; prefers river bottoms and stream banks',
#   'purple flowers in spring, about same time as flowering dogwood; fixes nitrogen'],
#  ['Chamaecrista fasciculata',
#   ' partridge pea, prairie senna',
#   'Caesalpiniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 3ft; ',
#   'yellow',
#   'Pod;         ',
#   'Full Sun',
#   'Sandy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'upland meadows, sandy fields, stream banks',
#   'pods coil after split open; spreads'],
#  ['Chamaecyparis thyoides',
#   ' Atlantic white cedar',
#   'Cupressaceae',
#   'Coastal Plain',
#   'DE, MD, VA',
#   'Tall Tree (Canopy)',
#   '75 - 75ft; ',
#   'greenish brown',
#   'Cone/Cone-like;          bluish',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'evergreen',
#   'NA',
#   'freshwater swamps or wet woods; best in acid-peat beds',
#   'NA'],
#  ['Chasmanthium latifolium',
#   ' wild oats, river oats, sea oats, spanglegrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '2 - 5ft; ',
#   'green then tan',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'NA',
#   'NA',
#   'streambank and alluvial woods',
#   'NA'],
#  ['Chelone glabra',
#   ' white turtlehead, turtlehead',
#   'Scrophulariaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'wet woods, stream banks, swamps, wet thickets',
#   'strong grower; herbal uses; host for Baltimore checkerspot butterfly'],
#  ['Chimaphila maculata',
#   " striped wintergreen, striped prince's pine",
#   'Pyrolaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry',
#   'June -          August',
#   'NA',
#   'Yes',
#   'acid, dry woods, frequently under pines',
#   'flowers fragrant'],
#  ['Chionanthus virginicus',
#   ' white fringetree',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'white',
#   'Berry;          bluish black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'NA',
#   'moist streambanks, ridges, and hillsides in sandy to deep-rich soils',
#   'NA'],
#  ['Chrysogonum virginianum',
#   ' green-and-gold, golden knees',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'open woods on limestone, rocky open woodland',
#   'will bloom longer if kept moist'],
#  ['Chrysopsis mariana',
#   ' golden aster, Maryland golden aster',
#   'Asteraceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '0.5 - 2.5ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry',
#   'July -          October',
#   'NA',
#   'Yes',
#   'dry sandy or argillaceous or rocky woods and openings, roadsides, serpentine barrens',
#   'NA'],
#  ['Cimicifuga racemosa',
#   ' black snakeroot, black cohosh, fairy candles',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2.5 - 8.5ft; ',
#   'white',
#   'Pod;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'June -          September',
#   'NA',
#   'NA',
#   'rich woods, wooded slopes, ravines, thickets',
#   'NA'],
#  ['Claytonia virginica',
#   ' narrowleaf spring beauty, spring beauty',
#   'Portulacaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white with pink',
#   'Capsule;         ',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'March -          May',
#   'NA',
#   'NA',
#   'rich woods, thickets and clearings, alluvial soils',
#   'NA'],
#  ['Clematis virginiana',
#   " virgin's bower",
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Vine',
#   '6 - 20ft; Spread: 6 - 12ft',
#   'white',
#   'Achene (dry, flat seed);          brown',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'yellow, green or purplish',
#   'NA',
#   'fencerows and thickets, riverbanks, low calcareous thickets, woods edge, roadside swales, swamps, overhanging cliffs',
#   'fragrant flowers; feathery seeds; young plants can be transplanted;yellow, green or purplish fall color'],
#  ['Clethra alnifolia',
#   ' sweet pepperbush, summersweet',
#   'Clethraceae',
#   'Coastal Plain',
#   'DE, DC, MD, NY, VA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 3 - 6ft',
#   'white/ pink',
#   'Capsule;          brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          August',
#   'yellow',
#   'NA',
#   'tidal and nontidal forested wetlands, shrub swamps, bogs, sandy woods, coastal river floodplains, lakeshores',
#   'very fragrant; tolerates some flooding by partly salty water'],
#  ['Clitoria mariana',
#   ' Maryland butterfly pea',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Herbaceous, Vine',
#   '6 - 6ft; ',
#   'pale blue or pinkish',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry',
#   'June -          September',
#   'NA',
#   'NA',
#   'dry, open areas on sandy soils',
#   'vine-like'],
#  ['Comptonia peregrina',
#   ' sweetfern',
#   'Myricacea',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 3ft; Spread: 3 - 6ft',
#   'yellow-green',
#   'Cone/Cone-like;          green to brown',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'April -          May',
#   'brown',
#   'NA',
#   'hillsides or dry cliffs, woods openings, sand flats and barrens, old fields, dunes',
#   'fragrant; fixes nitrogen, leaves may persist into winter'],
#  ['Conoclinium coelestinum',
#   ' mistflower, wild ageratum',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'blue, violet or purple',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'old fields, meadows; dry, sandy woodlands and clearings; damp thickets; stream banks',
#   'NA'],
#  ['Coreopsis tripteris',
#   ' tall coreopsis, tall tickseed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, VA, WV',
#   'Herbaceous',
#   '3.5 - 10ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          September',
#   'NA',
#   'NA',
#   'thickets, old fields, wood borders, roadsides',
#   'flower has anise scent'],
#  ['Cornus amomum',
#   ' silky dogwood, red willow, silky cornel',
#   'Cornaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white',
#   'Berry;          blue',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'May -          June',
#   'orange, red or purple',
#   'NA',
#   'forested seasonal wetlands and floodplains, shrub wetlands, stream and pond banks, clearings',
#   'NA'],
#  ['Cornus florida',
#   ' flowering dogwood',
#   'Cornaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 50ft; Spread: 20 - 50ft',
#   'white',
#   'Berry;          red to orange',
#   'Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          May',
#   'scarlet red',
#   'NA',
#   'woodland edges and openings; hardwood and mixed coniferous forests, mountain slopes, and coves',
#   'fall migrant birds eat berries; tolerates sun, best in moist, well-drained, acidic soil with organic matter, VA state tree'],
#  ['Crataegus crus-galli',
#   ' cockspur hawthorn',
#   'Rosaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'white',
#   'Fleshy;          dull red or green',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'orange to red',
#   'NA',
#   'thickets and open ground, especially in dry or rocky places; slopes of low hills in rich soils',
#   'NA'],
#  ['Crataegus viridis',
#   ' southern thorn, green hawthorn',
#   'Rosaceae',
#   'Coastal Plain',
#   'DE, MD, NY, VA',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; ',
#   'white',
#   'Fleshy;          bright red to orange',
#   'Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'April -          April',
#   'purple, scarlet',
#   'NA',
#   'moist soils in lowlands and valleys',
#   'NA'],
#  ['Danthonia spicata',
#   ' poverty oatgrass, poverty grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 2ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'Yes',
#   'open woods, old pastures, and meadows',
#   'NA'],
#  ['Dennstaedtia punctilobula',
#   ' hay-scented fern',
#   'Dennstaedtiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'open woods and fields',
#   'can spread over large areas of open understory or pasture'],
#  ['Desmodium paniculatum',
#   ' panicled or narrow-leaf tick-trefoil',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'purplish or green',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'clearings and borders of moist or dry woods',
#   'not found near coast'],
#  ['Dichanthelium clandestinum',
#   ' deer-tongue',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '2 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          October',
#   'NA',
#   'NA',
#   'moist woods, along roadsides',
#   'NA'],
#  ['Dichanthelium commutatum',
#   ' variable panicgrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '1 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          October',
#   'NA',
#   'NA',
#   'rocky or sandy woods',
#   'NA'],
#  ['Diospyros virginiana',
#   ' common persimmon',
#   'Ebenaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'greenish yellow to cream',
#   'Berry;          orange purple',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry, Moist',
#   'June -          June',
#   'yellow or purple',
#   'NA',
#   'open, disturbed areas and deciduous woodlands',
#   'edible fruits'],
#  ['Distichlis spicata',
#   ' saltgrass',
#   'Poaceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '0.5 - 1.5ft; ',
#   'NA',
#   'Pod;         ',
#   'Full Sun',
#   'Clay, Loamy',
#   'Flooded, Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'tidal salt marshes, from Mean High tide above to spring tide level; high salinity; wet depressions;',
#   'often intermixed with Spartina patens; forms dense mats; tolerates salinity to 50 ppt'],
#  ['Dryopteris cristata',
#   ' crested woodfern, crested shield fern, narrow swamp fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '1.5 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'NA',
#   'evergreen',
#   'Yes',
#   'shallow emergent marsh, shrub swamp, hardwood swamp; wooded swamps or open shrubby wetlands',
#   'small rosette fronds'],
#  ['Dryopteris intermedia',
#   ' evergreen wood-fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Fern',
#   '2.5 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'NA',
#   'evergreen',
#   'Yes',
#   'rich, moist to dry woods',
#   'clump-former; not common on coastal plain; hybridizes with eight species'],
#  ['Dryopteris marginalis',
#   ' marginal shield fern, evergreen wood fern, evergreen shield fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'NA',
#   'evergreen',
#   'Yes',
#   'moist woods and clearings',
#   'clump-former; attractive; easily transplanted'],
#  ['Dulichium arundinaceum',
#   ' three-sided sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'NA',
#   'Nut/Nut-like;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, bogs, swamps, pond edges',
#   'grows best where water rarely draws down'],
#  ['Elymus canadensis',
#   ' Canada wild rye',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '2 - 6.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          October',
#   'NA',
#   'NA',
#   'dry, sandy, gravely, or rocky soil',
#   'NA'],
#  ['Elymus hystrix',
#   ' bottlebrush grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '2 - 4ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'moist, alluvial woods',
#   'NA'],
#  ['Elymus riparius',
#   ' riverbank wild-rye',
#   'Poaceae',
#   'Coastal Plain, Piedmont',
#   'DE, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'rich thickets and stream borders, alluvial flats, meadows',
#   'good for streambank conditions'],
#  ['Elymus virginicus',
#   ' Virginia wild rye',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 5.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          October',
#   'NA',
#   'NA',
#   'rich thickets and shores, meadows',
#   'tolerates a wide range of conditions; forms clumps'],
#  ['Erigeron pulchellus',
#   " robin's plantain",
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'blue, pink, white',
#   'Capsule;         ',
#   'Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          September',
#   'NA',
#   'Yes',
#   'copses, open woods and meadows, wooded slopes, roadsides',
#   'NA'],
#  ['Eupatorium dubium',
#   ' Joe-Pye weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '2 - 5ft; ',
#   'purple, rarely white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'moist, usually sandy acidic soil of swamps, bogs, marshes, swales',
#   'NA'],
#  ['Eupatorium fistulosum',
#   ' Joe-Pye weed, trumpet weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 10ft; ',
#   'pink-purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'floodplains, meadows, moist thickets, roadsides',
#   'herbal uses'],
#  ['Eupatorium hyssopifolium',
#   ' hyssop-leaved thoroughwort, hyssop-leaved eupatori',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '1 - 4.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'dry, sandy or gravelly fields roadsides, and railroad right of ways; woods, fields, salt meadows',
#   'NA'],
#  ['Eupatorium perfoliatum',
#   ' common boneset',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'floodplains, swamps, bogs, streambanks, and wet meadows',
#   'NA'],
#  ['Eupatorium purpureum',
#   ' green-stemmed Joe-Pye weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2 - 6.5ft; ',
#   'pink, purple, cream',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'open woods fields and floodplains',
#   'occurs in drier, shadier habitats than other joe-pye-weeds; injured or dried plant has vanilla scent'],
#  ['Fagus grandifolia',
#   ' American beech',
#   'Fagaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 100ft; Spread: 50 - 75ft',
#   'yellow-green',
#   'Nut/Nut-like;          orange-green',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'yellow/tan; retains leaves till spring',
#   'NA',
#   'variety of soils, moist rich uplands and lowlands',
#   'edible nuts; attractive bark; leaves may persist into winter'],
#  ['Fraxinus americana',
#   ' white ash',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 100ft; Spread: 50 - 75ft',
#   'deep purple',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'yellow, maroon',
#   'NA',
#   'moist upland slopes, valleys, coves, and bottomlands',
#   'fast growth; fall color'],
#  ['Fraxinus pennsylvanica',
#   ' green ash, red ash, swamp ash',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'purple',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'April -          May',
#   'yellow to orange',
#   'NA',
#   'tidal freshwater forested wetlands; nontidal forested wetlands; regularly flooded',
#   'tolerates drought; tolerates infrequent flooding and some salt; male and female flowers on separate plants'],
#  ['Gaultheria procumbens',
#   ' wintergreen, checkerberry',
#   'Pyrolaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '0.5 - 0.5ft; Spread: 3 - 3ft',
#   'white to pink',
#   'Berry;          red',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          August',
#   'evergreen',
#   'Yes',
#   'sandy oak woods, clearings, steep rocky open slopes, deep mesic woods, hummocks in bogs',
#   'dense, mat-like form; forms colonies; edible fruits, leaves; wintergreen taste and scent'],
#  ['Gaylussacia baccata',
#   ' black huckleberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '1.5 - 3ft; Spread: 1 - 3ft',
#   'white to pink',
#   'Berry;          black',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'reddish-purple',
#   'NA',
#   'dry to wet woods and thickets',
#   'very common; fruits edible but many-seeded'],
#  ['Gaylussacia frondosa',
#   ' dangleberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, VA',
#   'Low Shrub',
#   '2 - 4ft; Spread: 2 - 4ft',
#   'greenish to purple',
#   'Berry;          blue',
#   'Full Sun, Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist, Wet',
#   'April -          June',
#   'reddish-purple',
#   'NA',
#   'dry to wet woods and thickets',
#   'berries borne on long, drooping stems'],
#  ['Gentiana clausa',
#   ' closed gentian, bottle gentian',
#   'Gentianaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'blue',
#   'Capsule;         ',
#   'Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'moist open woods, stream banks, meadows, in noncalcareous soils',
#   'NA'],
#  ['Geranium maculatum',
#   ' wild geranium, wood geranium',
#   'Geraniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2ft; ',
#   'lavender or pink',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'woods, roadsides, & fields',
#   'adaptable plant; long bloom time; spreader; herbal uses; explosive seed capsule'],
#  ['Goodyera pubescens',
#   ' downy rattlesnake plantain',
#   'Orchidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'whitish',
#   'NA',
#   'Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'dry to moist deciduous or coniferous forests',
#   'very handsome throughout winter'],
#  ['Hamamelis virginiana',
#   ' witch hazel',
#   'Hamamelidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '15 - 30ft; Spread: 20 - 30ft',
#   'yellow',
#   'Capsule;          tan brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'September -          December',
#   'yellow',
#   'NA',
#   'woodland or brushy fields, moist or dry',
#   'noted for fall/winter bloom; medicinal uses, leaves may persist into winter'],
#  ['Helenium autumnale',
#   ' yellow sneezeweed, common sneezeweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'July -          November',
#   'NA',
#   'NA',
#   'low woods, swamps, moist riverbanks, alluvial thickets, wet meadows, marshes, ditches',
#   'tolerates wet areas; showy flowers; herbal uses'],
#  ['Helianthus angustifolius',
#   ' swamp sunflower',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '1.5 - 5.5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'swamps and moist, sandy ground',
#   'NA'],
#  ['Helianthus decapetalus',
#   ' ten-petaled sunflower, thin-leaved sunflower',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'fields, moist bottomlands, stream banks, roadsides',
#   'NA'],
#  ['Helianthus divaricatus',
#   ' woodland sunflower, rough sunflower',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Partial Sun',
#   'Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'NA',
#   'NA',
#   'dry open woods, wooded slopes, shale barrens, roadsides',
#   'NA'],
#  ['Heliopsis helianthoides',
#   ' oxeye sunflower, oxeye',
#   'Asteraceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'pale yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'June -          September',
#   'NA',
#   'NA',
#   'fields, open woods, floodplains, thickets, stream banks',
#   'long bloom time'],
#  ['Hepatica nobilis var. obtusa',
#   ' round-lobed hepatica, liverleaf',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 2ft; ',
#   'white to lavender',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'dry or rocky woods, dry upland slopes',
#   'NA'],
#  ['Heracleum maximum',
# ...
#   'deciduous conifer'],
#  ['Thalictrum dioicum',
#   ' early meadow rue',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'green to purple',
#   'Capsule;         ',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'April -          May',
#   'NA',
#   'NA',
#   'rich rocky woods, ravines, alluvial terraces',
#   'NA'],
#  ['Thalictrum pubescens',
#   ' tall meadow rue',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 9ft; ',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'rich woods, low thickets, swamps, wet meadows, stream banks',
#   'foliage similar to columbines; clump-forming; delicate flowers; species very variable'],
#  ['Thalictrum thalictroides',
#   ' rue anemone, windflower',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'wooded banks and thickets',
#   'foliage similar to columbines'],
#  ['Thelypteris noveboracensis',
#   ' New York fern',
#   'Thelypteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'forested wetlands, dry to damp woods and thickets',
#   'tolerates drought; easily transplanted; forms large colonies; spreads easily'],
#  ['Thelypteris palustris',
#   ' marsh fern',
#   'Thelypteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '2 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'swamps, bogs, wet fields or thickets, fresh tidal and nontidal marshes, wooded streambanks',
#   'spreads'],
#  ['Tiarella cordifolia',
#   ' foamflower, false miterwort, heartleaf foamflower',
#   'Saxifragaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'rich woods, moist rocky wooded slopes',
#   'attractive, long-blooming; creeping, clump-forming; many cultivars'],
#  ['Tradescantia virginiana',
#   " Virginia spiderwort, widow's tears",
#   'Commelinaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'deep blue-purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'NA',
#   'wooded slopes, shale outcrops, moist fields, roadsides',
#   'flowers showy'],
#  ['Tridens flavus',
#   ' redtop, purpletop',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Grass/Grasslike',
#   '2 - 6.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'dry fields, roadsides, openings, borders of woods',
#   'NA'],
#  ['Trillium grandiflorum',
#   ' white trillium, large-flowered trillium',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'white then pink',
#   'Berry;          black',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'moist woods',
#   'showy flowers; common, often in large colonies'],
#  ['Tripsacum dactyloides',
#   ' gama grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '6 - 10ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'swales, moist fields, borders of woods, shores',
#   'excellent forage grass; often grows wild near corn fields; can hybridize with corn'],
#  ['Ulmus americana',
#   ' American elm, white elm, soft elm',
#   'Ulmaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '75 - 100ft; Spread: 75 - 100ft',
#   'red brown',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'bright yellow',
#   'NA',
#   'river bottoms, swamps, disturbed fields, road sides, cutover forests',
#   'Dutch elm disease caused decline; distinctive "vase" shape; favorite nesting site of Baltimore oriole'],
#  ['Uvularia perfoliata',
#   ' perfoliate bellwort, mealy bellwort',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 2ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'NA',
#   'moist woods',
#   'rhizome can be cooked and eaten; young shoots maybe substituted for asparagus'],
#  ['Uvularia sessilifolia',
#   ' straw lily',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'NA',
#   'Yes',
#   'dry to moist woodland',
#   'rhizomes may be cooked and eaten; young shoots may be substituted for asparagus'],
#  ['Vaccinium corymbosum',
#   ' highbush blueberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white or pink-tinged',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'April -          June',
#   'yellow to red',
#   'NA',
#   'forested wetlands, shrub swamps, bogs, upland woods; dry to wet woods, thickets, stream banks, rock outcroppings',
#   'edible berries commonly cultivated'],
#  ['Vaccinium macrocarpon',
#   ' cranberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, PA, WV',
#   'Low Shrub',
#   '0.5 - 1ft; Spread: 3 - 3ft',
#   'white to pink',
#   'Berry;          red',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Wet',
#   'June -          July',
#   'dark green to purple to red',
#   'Yes',
#   'sphagnum bogs, cool wet swampy ground',
#   'low mat form, can spread indefinitely; edible cranberries'],
#  ['Vaccinium pallidum',
#   ' early lowbush blueberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Low Shrub',
#   '1.5 - 2ft; ',
#   'white, reddish',
#   'Berry;          blue',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          May',
#   'NA',
#   'Yes',
#   'dry woods and barrens',
#   'sweet berries'],
#  ['Vaccinium stamineum',
#   ' deerberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white or purple',
#   'Berry;          bluish black',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'red',
#   'NA',
#   'dry woods, openings, barrens; dry upland oak woods, floodplain forests, clearings and thickets, pine woods and barrens, rock outcroppings',
#   'berries edible but sour'],
#  ['Veratrum viride',
#   ' green false hellebore, white hellebore',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2 - 5ft; ',
#   'yellow-green',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'May -          July',
#   'NA',
#   'NA',
#   'swamps & wet woods',
#   'leaf edges will brown if soil dries and plant is in windy area; does best in cooler temps; slugs like the foliage'],
#  ['Verbena hastata',
#   " blue vervain, simpler's joy",
#   'Verbenaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '1.5 - 5ft; ',
#   'blue to purple',
#   'Nut/Nut-like;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'moist meadows, swamps floodplains, wet ditches, roadsides',
#   'bright flowers; herbal uses'],
#  ['Verbesina alternifolia',
#   ' wingstem, yellow ironweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '3.5 - 8ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun',
#   'NA',
#   'Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'moist wooded slopes and open woodlands, riverbanks, shaded lowlands, roadsides, fields',
#   'threatened in NY'],
#  ['Vernonia noveboracensis',
#   ' New York ironweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '3.5 - 8ft; ',
#   'purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'stream banks, wet fields, fresh water marshes',
#   'brilliant flowers; tall upright form adds structure to garden; spreads'],
#  ['Viburnum acerifolium',
#   ' maple-leaved arrowwood',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 6ft; Spread: 3 - 6ft',
#   'creamy-white, pink',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist',
#   'June -          June',
#   'orange, red, purple',
#   'NA',
#   'floodplain forests, dry wooded slopes, mixed deciduous forests, talus slopes, rock outcrops, wooded ravines',
#   'dry, edible berries'],
#  ['Viburnum dentatum',
#   ' southern arrowwood',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub, Tall Shrub',
#   '10 - 15ft; Spread: 6 - 12ft',
#   'white',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'reddish-purple',
#   'NA',
#   'swamps and wet woods, bogs, floodplain forests, stream banks; low, wet acid-sand habitats',
#   'stems very straight, nice structure in winter'],
#  ['Viburnum nudum',
#   ' naked witherod, possum-haw viburnum',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA',
#   'Medium Shrub',
#   '6.5 - 20ft; Spread: 12 - 20ft',
#   'white to cream',
#   'Berry;          red to blue, then black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'June -          July',
#   'red to purple',
#   'NA',
#   'wet woods, swamps, margins of vernal ponds, heath bogs, deep rich upland forests, creek bottoms, wet sandy woods',
#   'edible fruit but very acidic; shallow fibrous roots, transplants well'],
#  ['Viburnum nudum var. cassinoides',
#   ' witherod',
#   'Adoxaceae, Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'MD, PA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'creamy white',
#   'Berry;          pink to blue-black',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'orange-red to purple',
#   'NA',
#   'swamps, bogs, moist woods, and barrens',
#   'handsome stature; multiple fruit colors at once'],
#  ['Viburnum prunifolium',
#   ' black haw',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '12 - 24ft; Spread: 8 - 12ft',
#   'white',
#   'Berry;          pink to bluish-black',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'April -          May',
#   'reddish purple',
#   'NA',
#   'successional woods, thickets, old fields, and roadsides',
#   'fruits edible, used for preserves'],
#  ['Viola conspersa',
#   ' American dog violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'pale blue, violet',
#   'Capsule;          green',
#   'Full Sun, Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'April -          July',
#   'NA',
#   'Yes',
#   'moist woods, damp fields, swamps',
#   'delicate plant and flower; edible'],
#  ['Viola cucullata',
#   ' marsh blue violet, blue marsh violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, PA, VA, WV',
#   'Herbaceous',
#   'NA',
#   'pale purple',
#   'Capsule;          green',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          July',
#   'NA',
#   'Yes',
#   'bogs, meadows, & swamps',
#   'stemless; self-sows; can become a nuisance'],
#  ['Viola pedata',
#   " bird's foot violet",
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Herbaceous',
#   'NA',
#   'pale blue or w/ purple-black tips',
#   'Capsule;          green',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'sandy or rocky barrens, dry forested slopes',
#   'stemless'],
#  ['Viola sororia',
#   ' common blue violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'dark blue, violet',
#   'Capsule;          green with purple',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist',
#   'March -          June',
#   'NA',
#   'NA',
#   'dry to moist woods, swamps, thickets',
#   'delicate plant and flower; edible; spreader; stemless'],
#  ['Viola striata',
#   ' striped cream violet, striped violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'ivory w/ purple',
#   'Capsule;          green',
#   'Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'April -          June',
#   'NA',
#   'NA',
#   'alluvial woods, alkaline swamps, moist fields',
#   'NA'],
#  ['Wisteria frutescens',
#   ' Atlantic wisteria, American wisteria',
#   'Fabaceae',
#   'Coastal Plain',
#   'DE, VA',
#   'Vine',
#   '20 - 20ft; ',
#   'lilac',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          August',
#   'NA',
#   'NA',
#   'borders of wooded swamps and wet woodlands, stream banks, moist or wet thickets',
#   'NA'],
#  ['Woodwardia areolata',
#   ' netted chain fern',
#   'Blechnaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '0.5 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'mostly acid bogs, swamps, or wet woods',
#   'spreads by creeping rhizome'],
#  ['Woodwardia virginica',
#   ' Virginia chain fern',
#   'Blechnaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '3 - 6ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'swampy places, wet woods',
#   'spreads by creeping rhizome'],
#  ['Yucca filamentosa',
#   " Adam's needle",
#   'Agavaceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '2 - 2.5ft; ',
#   'white',
#   'NA',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'June -          September',
#   'NA',
#   'NA',
#   'coastal sand dunes; outcroppings on thin rocky soils',
#   'flower stalk can rise 5-15 feet above foliage'],
#  ['Zizania aquatica',
#   ' wild rice',
#   'Poaceae',
#   'Coastal Plain',
#   'DE, DC, MD, NY, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '6 - 10ft; ',
#   'NA',
#   'Achene (dry, flat seed);         ',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'June -          September',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, stream borders, shallow waters',
#   'annual; edible'],
#  ['Zizia aurea',
#   ' golden-alexanders',
#   'Apiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'wooded bottomland, stream banks, moist meadows, floodplain',
#   'NA']]

# %%
# Data Validation
# quickly scanning the list to find any potential abnormalities.
plant_info
# Out:
# [['Binomial',
#   'Common Names',
#   'Family',
#   'Regions',
#   'States',
#   'Plant Types',
#   'Height',
#   'Flower Color',
#   'Fruit',
#   'Sun Exposure',
#   'Soil Texture',
#   'Soil Moisture',
#   'Blooms',
#   'Fall Color',
#   'Ground Cover',
#   'Habitat',
#   'Notes'],
#  ['Acer negundo',
#   ' box elder, ash leaf maple, Manitoba maple',
#   'Aceraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '30 - 60ft; Spread: 30 - 60ft',
#   'yellow-green',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow, red',
#   'NA',
#   'grows best in lowland sites along rivers, streams, ponds, and seasonally flooded areas; tolerates a variety of soil types',
#   'brittle wood; thicket-forming'],
#  ['Acer rubrum',
#   ' red maple, scarlet maple, swamp maple, soft maple',
#   'Aceraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '40 - 100ft; Spread: 30 - 75ft',
#   '(inconspicuous)',
#   'Winged;          red-brown or yellow',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'red, orange, yellow',
#   'NA',
#   'swamps, uplands;  occasionally on dry rocky hillsides and sanddunes',
#   'earliest spring bloomer; adaptable'],
#  ['Actaea pachypoda',
#   " doll's eyes",
#   'Ranunculaceae',
#   'Coastal Plain',
#   'DE, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'whitish',
#   'Berry;          white or red',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'rich open woods, thickets',
#   'interesting berries; infrequent in Piedmont and mountain regions'],
#  ['Adiantum pedatum',
#   ' northern maidenhair fern',
#   'Pteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Fern',
#   '1 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'rich, moist woods; rocky well-shaded habitats, protected from dryness or direct sunlight',
#   'grows in clumps; delicate texture; herbal uses'],
#  ['Agalinis purpurea',
#   ' purple false foxglove',
#   'Scrophulariaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '1 - 4ft; ',
#   'rose-purple, white',
#   'Capsule;         ',
#   'Full Sun',
#   'Sandy',
#   'Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'moist sandy fields, rocky shores, serpentine barrens',
#   'NA'],
#  ['Ageratina altissima var. altissima',
#   ' white snakeroot',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'rich woods, thickets, clearings, meadows',
#   'tough plant; cultivars available; prefers basic soils'],
#  ['Agrostis perennans',
#   ' autumn bentgrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, PA, VA, WV',
#   'Grass/Grasslike',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'dry or moist thickets, open woods, unshaded areas',
#   'NA'],
#  ['Alnus serrulata',
#   ' smooth alder, hazel alder',
#   'Betulaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Shrub',
#   '12 - 20ft; Spread: 12 - 20ft',
#   'purple',
#   'Cone/Cone-like;          brown',
#   'Full Sun',
#   'Clay, Loamy',
#   'Flooded, Moist, Wet',
#   'March -          April',
#   'yellow, red',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands',
#   'forms thickets along watercourses; nitrogen fixing; tolerates flooding to 3"'],
#  ['Amelanchier canadensis',
#   ' serviceberry, shadbush, shadblow serviceberry, Canadian serviceberry',
#   'Rosaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA',
#   'Small/Medium Tree (Understory)',
#   '35 - 50ft; Spread: 35 - 50ft',
#   'white',
#   'Fleshy;          red to purple',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'orange to red',
#   'NA',
#   'swamps, low ground, woods, & thickets',
#   'NA'],
#  ['Ammophila breviligulata',
#   ' dunegrass, American beachgrass',
#   'Poaceae',
#   'Coastal Plain',
#   'VA',
#   'Grass/Grasslike',
#   '1.5 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'maritime beach/dunes, maritime grassland, maritime shrubland',
#   'prefers well-drained, sandy sites; spreads rapidly by rhizomes'],
#  ['Andropogon glomeratus',
#   ' bushy bluestem',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1.5 - 5ft; ',
#   'reddish brown',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'August -          October',
#   'reddish',
#   'NA',
#   'fresh marshes, wet soils, coastal areas',
#   'tolerates drought; grows in tufts; reddish fall color'],
#  ['Andropogon virginicus',
#   ' broomsedge',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3ft; ',
#   'reddish brown',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'August -          November',
#   'reddish-tan',
#   'NA',
#   'wet meadows, transition areas; poor soils',
#   'wildlife food and cover; tolerates drought; grows in tufts; reddish-tan fall color'],
#  ['Aquilegia canadensis',
#   ' eastern or wild columbine',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 3ft; ',
#   'red-yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'rich rocky woods and slopes, cliffs, ledges, pastures, and roadside banks; rarely in swamps',
#   'commonly cultivated; spreads by seed'],
#  ['Aralia nudicaulis',
#   ' wild sarsaparilla',
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'white or green',
#   'Berry;          purple-black',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'NA',
#   'dry to moist woods',
#   'aromatic; single-leaved; lacks an above-ground stem; not common in coastal plain'],
#  ['Aralia racemosa',
#   ' spikenard',
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'greenish-white',
#   'Berry;          dark purple',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'rich woods and thickets, wooded slopes and edges',
#   'not common in coastal plain'],
#  ['Aralia spinosa',
#   " Devil's walking stick",
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Tall Shrub',
#   '20 - 30ft; Spread: 12 - 20ft',
#   'white',
#   'Berry;          black',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          August',
#   'yellow',
#   'NA',
#   'moist woods, stream banks, roadsides',
#   'seeds are poisonous if chewed; low maintenance; spreads from new shoots; thorny, clublike stem'],
#  ['Arisaema triphyllum',
#   ' Jack-in-the-pulpit',
#   'Araceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'striped, purple or green',
#   'Berry;         ',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'March -          June',
#   'NA',
#   'NA',
#   'wet woods, bogs and swamps',
#   'red berry clusters appear late summer to fall; unusual flower; spreads rapidly from seed'],
#  ['Asarum canadense',
#   ' wild ginger',
#   'Aristolochiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'brownish-purple',
#   'Capsule;          brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'semi-evergreen',
#   'Yes',
#   'rich woodlands, less so on acid soils',
#   'flower inconspicuous; attractive leaves; will spread; semi-evergreen'],
#  ['Asclepias incarnata',
#   ' swamp milkweed',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '4 - 6ft; ',
#   'pink to reddish',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'May -          June',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, wet meadows, shrub swamps, clearings of wet woods, shores and ditches',
#   'can tolerate drought; interesting seed pod'],
#  ['Asclepias syriaca',
#   ' common milkweed',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '3.5 - 6.5ft; ',
#   'pale purple',
#   'Pod;         ',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'May -          August',
#   'NA',
#   'NA',
#   'thickets, roadsides, dry fields',
#   'interesting seed pods; fragrant flower'],
#  ['Asclepias tuberosa',
#   ' butterflyweed, butterfly milkweed, butterfly flower',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'orange',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'NA',
#   'dry fields, roadsides and shale barrens',
#   'taproot does not transplant well but seedlings do; attractive seed pod'],
#  ['Asimina triloba',
#   ' paw-paw',
#   'Annonaceae',
#   'Coastal Plain',
#   'DE, DC, MD, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'purple',
#   'Berry;          yellow',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'April -          June',
#   'yellow/copper-red',
#   'NA',
#   'deep, rich, moist soils of river valleys and bottomlands.  Also in the understory of hardwood forests.',
#   'NA'],
#  ['Asplenium platyneuron',
#   ' ebony spleenwort',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, VA, WV',
#   'Fern',
#   '0.5 - 1.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'NA',
#   'evergreen',
#   'Yes',
#   'sandy or clayey banks, open woods and thickets, slopes, rocky ledges, swamps',
#   'easily transplanted; only moderate care needed; evergreen'],
#  ['Athyrium filix-femina',
#   ' northern lady fern',
#   'Dryopteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Partial Sun',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'wet woods, moist banks, wooded hillsides, sandy bogs',
#   'varieties occur throughout region; in MD, VA can also use subspecies asplenioides (southern lady fern)'],
#  ['Baccharis halimifolia',
#   ' high-tide bush, groundsel tree, sea myrtle',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, MD, VA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white',
#   'Achene (dry, flat seed);          silvery white',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'August -          September',
#   'purple',
#   'NA',
#   'salt or brackish marshes, fresh tidal marshes and ditches, shores, dunes',
#   'volunteers in disturbed places; shallow, lateral roots; tolerates flooding to 6"; tolerates salinity to 15 ppt'],
#  ['Baptisia tinctoria',
#   ' yellow wild indigo',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'May -          September',
#   'NA',
#   'NA',
#   'dry open woods and clearings, sandy acidic soil',
#   'tolerates poor soils'],
#  ['Betula nigra',
#   ' river birch, red birch, black birch',
#   'Betulaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'dark brown',
#   'Cone/Cone-like;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'lowland species mainly along streams, rivers, ponds, and swamps',
#   'attractive peeling bark;'],
#  ['Bidens cernua',
#   ' nodding beggar-ticks, nodding bur marigold',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '0.5 - 3ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'tidal marsh, sloughs, springs, pools, shore',
#   'NA'],
#  ['Bignonia capreolata',
#   ' crossvine',
#   'Bignoniaceae',
#   'Coastal Plain',
#   'MD, VA',
#   'Vine',
#   '30 - 45ft; Spread: 20 - 35ft',
#   'orange with red',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'semi-evergreen; reddish-purple',
#   'Yes',
#   'alluvial woods, swampy forests, calcareous soils on river banks, cliffs in ravines, dry open woods, bogs, fence rows, rock outcrops',
#   'spreads across ground and climbs any structure it meets (control by cutting); semi-evergreen'],
#  ['Boltonia asteroides',
#   " star boltonia, white doll's daisy",
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, VA, WV',
#   'Herbaceous',
#   '0.5 - 2.5ft; ',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'gravelly shores, sandy thickets',
#   'NA'],
#  ['Botrychium virginianum',
#   ' rattlesnake fern',
#   'Ophioglossaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'rich, well-drained, wooded areas',
#   'NA'],
#  ['Callicarpa americana',
#   ' American beautyberry, French mulberry',
#   'Verbenaceae',
#   'Coastal Plain',
#   'DC, VA',
#   'Medium Shrub',
#   '6 - 6ft; Spread: 6 - 6ft',
#   'lavender-pink',
#   'Berry;          lavender',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'in most soils',
#   'flowers from new growth; if overgrown prune to 6-18" tall; will regain height in one season'],
#  ['Caltha palustris',
#   ' marsh marigold',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '1 - 2ft; ',
#   'bright yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Flooded, Wet',
#   'April -          June',
#   'NA',
#   'NA',
#   'forested wetlands, shrub swamps, streambanks, seeps, wet meadows',
#   'clump-forming; needs some periods of drier soil; tolerates flooding to 6"'],
#  ['Campsis radicans',
#   ' trumpet vine, trumpet creeper',
#   'Bignoniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA',
#   'Vine',
#   '30 - 30ft; Spread: 20 - 35ft',
#   'orange',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'yellow green',
#   'Yes',
#   'moist woodlands, fence rows, roadside thickets, floodplain forests, rock hillsides, open woods, stream banks, old fields',
#   'thick, twisted, aged woody vines; leaves/flowers may cause dermatitis (skin irritation)'],
#  ['Carex crinita var. crinita',
#   ' long hair sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'swales, damp thickets, and low woods',
#   'NA'],
#  ['Carex glaucodea',
#   ' blue wood sedge',
#   'Cyperaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Grass/Grasslike',
#   '0.5 - 2ft; ',
#   'brown to reddish',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'Yes',
#   'moist to dry woods and fields',
#   'clump-forming; alternative to Liriope'],
#  ['Carex lurida',
#   ' sallow sedge, lurid sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'swales, swamps, and wet woods',
#   'wetland plant; interesting seeds'],
#  ['Carex pensylvanica',
#   ' Pennsylvania sedge',
#   'Cyperaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 1.5ft; ',
#   'reddish to white',
#   'NA',
#   'Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'open dry soil or open woods; dry or sandy, open or rocky oak woods, wooded slopes; clump-forming',
#   'alternative to lawn; plant densely; fine textured leaves <6"'],
#  ['Carex stricta',
#   ' tussock sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'reddish to purple brown',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'May -          August',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands, wet swales, moist fields',
#   'grows in clumps; partly persists in winter; tolerates flooding to 6"'],
#  ['Carex vulpinoidea',
#   ' fox sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '0.5 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Flooded, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'shallow emergent marsh, shrub swamp, floodplain forest, hardwood swamp',
#   'grows in clumps; tolerates saturation and flooding to 6"'],
#  ['Carya alba',
#   ' mockernut hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 35 - 50ft',
#   'light green',
#   'Nut/Nut-like;          light reddish brown',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'NA',
#   'ridges, dry hills, and hillsides; rich well drained soils',
#   'good fall color'],
#  ['Carya cordiformis',
#   ' bitternut hickory, swamp hickory, pignut, bitternut',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 60 - 100ft',
#   'yellow-green',
#   'Nut/Nut-like;          yellowish green',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'can grow in swamps and frequently flooded areas and dry hillsides; does best in rich bottomlands',
#   'NA'],
#  ['Carya glabra',
#   ' pignut hickory, sweet pignut hickory, smooth bark hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 35 - 50ft',
#   'yellow-green',
#   'Nut/Nut-like;          dark brown',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'dry woods, primarily on hillsides and along dry ridges; does best in deep, moist, well drained soils',
#   'NA'],
#  ['Carya ovata',
#   ' shagbark hickory, scalybark hickory, shellbark hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '70 - 100ft; Spread: 35 - 50ft',
#   'yellow-green',
#   'Nut/Nut-like;          dark or reddish brown',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'May -          June',
#   'brown',
#   'NA',
#   'both dry upland slopes to 2,000 feet, and deep well-drained soils in lowlands and valleys',
#   'attractive peeling bark'],
#  ['Castanea pumila',
#   ' chinquapin, chinkapin, eastern chinkapin, Allegany chinkapin',
#   'Fagaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '12 - 20ft; Spread: 12 - 20ft',
#   'pale yellow',
#   'Nut/Nut-like;          dark brown',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'June -          June',
#   'yellow or purple',
#   'NA',
#   'dry rocky slopes, dry woods, steep rocky land, rocky stream banks, sandy ridges, borders of swamps, open woods',
#   'sweet, edible fruit'],
#  ['Caulophyllum thalictroides',
#   ' blue cohosh',
#   'Berberidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'green-yellow, green-purple',
#   'Berry;          dark blue',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'moist rich woods',
#   'NA'],
#  ['Ceanothus americanus',
#   ' New Jersey tea',
#   'Rhamnaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 3ft; Spread: 3 - 6ft',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry',
#   'May -          September',
#   'yellow to tan',
#   'NA',
#   'meadow, old field, glade, forest; dry open woods and borders, rocky areas, openings',
#   'tough; tolerates moist soil if well drained; fixes nitrogen; tolerates dryness'],
#  ['Celastrus scandens',
#   ' American bittersweet',
#   'Celastraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Vine',
#   '3 - 35ft; Spread: 6 - 20ft',
#   'greenish',
#   'Capsule;          orange and red',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'Yes',
#   'roadsides, woods edge, fence rows, old pastures, hedges, rocky streams, bluffs, rocky slopes, dunes, sandy oak woods',
#   'distinguished from nonnative invasive Oriental bittersweet by flowers/fruits in clusters at ends of twigs'],
#  ['Celtis occidentalis',
#   ' common hackberry, sugarberry, nettletree',
#   'Ulmaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '40 - 100ft; Spread: 40 - 100ft',
#   'yellow green, brown tint',
#   'Berry;          purple brown',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'drainage basins, mature floodplains, wooded slopes or high rocky limestone bluffs bordering streams, windbreaks',
#   'butterfly larval host; drought tolerant; tolerates occasional flooding; saplings can sprout in deep shade, common on limestone soils'],
#  ['Cephalanthus occidentalis',
#   ' buttonbush',
#   'Rubiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 12 - 20ft',
#   'creamy white',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'July -          August',
#   'yellow-green',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands, borders of streams, lakes, and ponds',
#   'needs sun to flower; flowers fragrant; interesting fruit; tolerates drought; leaves may persist into winter; tolerates flooding to 36"'],
#  ['Cercis canadensis',
#   ' eastern redbud',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'pink to lavender',
#   'Pod;          black',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          May',
#   'golden yellow',
#   'NA',
#   'rich, moist sites; prefers river bottoms and stream banks',
#   'purple flowers in spring, about same time as flowering dogwood; fixes nitrogen'],
#  ['Chamaecrista fasciculata',
#   ' partridge pea, prairie senna',
#   'Caesalpiniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 3ft; ',
#   'yellow',
#   'Pod;         ',
#   'Full Sun',
#   'Sandy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'upland meadows, sandy fields, stream banks',
#   'pods coil after split open; spreads'],
#  ['Chamaecyparis thyoides',
#   ' Atlantic white cedar',
#   'Cupressaceae',
#   'Coastal Plain',
#   'DE, MD, VA',
#   'Tall Tree (Canopy)',
#   '75 - 75ft; ',
#   'greenish brown',
#   'Cone/Cone-like;          bluish',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'evergreen',
#   'NA',
#   'freshwater swamps or wet woods; best in acid-peat beds',
#   'NA'],
#  ['Chasmanthium latifolium',
#   ' wild oats, river oats, sea oats, spanglegrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '2 - 5ft; ',
#   'green then tan',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'NA',
#   'NA',
#   'streambank and alluvial woods',
#   'NA'],
#  ['Chelone glabra',
#   ' white turtlehead, turtlehead',
#   'Scrophulariaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'wet woods, stream banks, swamps, wet thickets',
#   'strong grower; herbal uses; host for Baltimore checkerspot butterfly'],
#  ['Chimaphila maculata',
#   " striped wintergreen, striped prince's pine",
#   'Pyrolaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry',
#   'June -          August',
#   'NA',
#   'Yes',
#   'acid, dry woods, frequently under pines',
#   'flowers fragrant'],
#  ['Chionanthus virginicus',
#   ' white fringetree',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'white',
#   'Berry;          bluish black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'NA',
#   'moist streambanks, ridges, and hillsides in sandy to deep-rich soils',
#   'NA'],
#  ['Chrysogonum virginianum',
#   ' green-and-gold, golden knees',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'open woods on limestone, rocky open woodland',
#   'will bloom longer if kept moist'],
#  ['Chrysopsis mariana',
#   ' golden aster, Maryland golden aster',
#   'Asteraceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '0.5 - 2.5ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry',
#   'July -          October',
#   'NA',
#   'Yes',
#   'dry sandy or argillaceous or rocky woods and openings, roadsides, serpentine barrens',
#   'NA'],
#  ['Cimicifuga racemosa',
#   ' black snakeroot, black cohosh, fairy candles',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2.5 - 8.5ft; ',
#   'white',
#   'Pod;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'June -          September',
#   'NA',
#   'NA',
#   'rich woods, wooded slopes, ravines, thickets',
#   'NA'],
#  ['Claytonia virginica',
#   ' narrowleaf spring beauty, spring beauty',
#   'Portulacaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white with pink',
#   'Capsule;         ',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'March -          May',
#   'NA',
#   'NA',
#   'rich woods, thickets and clearings, alluvial soils',
#   'NA'],
#  ['Clematis virginiana',
#   " virgin's bower",
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Vine',
#   '6 - 20ft; Spread: 6 - 12ft',
#   'white',
#   'Achene (dry, flat seed);          brown',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'yellow, green or purplish',
#   'NA',
#   'fencerows and thickets, riverbanks, low calcareous thickets, woods edge, roadside swales, swamps, overhanging cliffs',
#   'fragrant flowers; feathery seeds; young plants can be transplanted;yellow, green or purplish fall color'],
#  ['Clethra alnifolia',
#   ' sweet pepperbush, summersweet',
#   'Clethraceae',
#   'Coastal Plain',
#   'DE, DC, MD, NY, VA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 3 - 6ft',
#   'white/ pink',
#   'Capsule;          brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          August',
#   'yellow',
#   'NA',
#   'tidal and nontidal forested wetlands, shrub swamps, bogs, sandy woods, coastal river floodplains, lakeshores',
#   'very fragrant; tolerates some flooding by partly salty water'],
#  ['Clitoria mariana',
#   ' Maryland butterfly pea',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Herbaceous, Vine',
#   '6 - 6ft; ',
#   'pale blue or pinkish',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry',
#   'June -          September',
#   'NA',
#   'NA',
#   'dry, open areas on sandy soils',
#   'vine-like'],
#  ['Comptonia peregrina',
#   ' sweetfern',
#   'Myricacea',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 3ft; Spread: 3 - 6ft',
#   'yellow-green',
#   'Cone/Cone-like;          green to brown',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'April -          May',
#   'brown',
#   'NA',
#   'hillsides or dry cliffs, woods openings, sand flats and barrens, old fields, dunes',
#   'fragrant; fixes nitrogen, leaves may persist into winter'],
#  ['Conoclinium coelestinum',
#   ' mistflower, wild ageratum',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'blue, violet or purple',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'old fields, meadows; dry, sandy woodlands and clearings; damp thickets; stream banks',
#   'NA'],
#  ['Coreopsis tripteris',
#   ' tall coreopsis, tall tickseed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, VA, WV',
#   'Herbaceous',
#   '3.5 - 10ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          September',
#   'NA',
#   'NA',
#   'thickets, old fields, wood borders, roadsides',
#   'flower has anise scent'],
#  ['Cornus amomum',
#   ' silky dogwood, red willow, silky cornel',
#   'Cornaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white',
#   'Berry;          blue',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'May -          June',
#   'orange, red or purple',
#   'NA',
#   'forested seasonal wetlands and floodplains, shrub wetlands, stream and pond banks, clearings',
#   'NA'],
#  ['Cornus florida',
#   ' flowering dogwood',
#   'Cornaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 50ft; Spread: 20 - 50ft',
#   'white',
#   'Berry;          red to orange',
#   'Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          May',
#   'scarlet red',
#   'NA',
#   'woodland edges and openings; hardwood and mixed coniferous forests, mountain slopes, and coves',
#   'fall migrant birds eat berries; tolerates sun, best in moist, well-drained, acidic soil with organic matter, VA state tree'],
#  ['Crataegus crus-galli',
#   ' cockspur hawthorn',
#   'Rosaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'white',
#   'Fleshy;          dull red or green',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'orange to red',
#   'NA',
#   'thickets and open ground, especially in dry or rocky places; slopes of low hills in rich soils',
#   'NA'],
#  ['Crataegus viridis',
#   ' southern thorn, green hawthorn',
#   'Rosaceae',
#   'Coastal Plain',
#   'DE, MD, NY, VA',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; ',
#   'white',
#   'Fleshy;          bright red to orange',
#   'Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'April -          April',
#   'purple, scarlet',
#   'NA',
#   'moist soils in lowlands and valleys',
#   'NA'],
#  ['Danthonia spicata',
#   ' poverty oatgrass, poverty grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 2ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'Yes',
#   'open woods, old pastures, and meadows',
#   'NA'],
#  ['Dennstaedtia punctilobula',
#   ' hay-scented fern',
#   'Dennstaedtiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'open woods and fields',
#   'can spread over large areas of open understory or pasture'],
#  ['Desmodium paniculatum',
#   ' panicled or narrow-leaf tick-trefoil',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'purplish or green',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'clearings and borders of moist or dry woods',
#   'not found near coast'],
#  ['Dichanthelium clandestinum',
#   ' deer-tongue',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '2 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          October',
#   'NA',
#   'NA',
#   'moist woods, along roadsides',
#   'NA'],
#  ['Dichanthelium commutatum',
#   ' variable panicgrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '1 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          October',
#   'NA',
#   'NA',
#   'rocky or sandy woods',
#   'NA'],
#  ['Diospyros virginiana',
#   ' common persimmon',
#   'Ebenaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'greenish yellow to cream',
#   'Berry;          orange purple',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry, Moist',
#   'June -          June',
#   'yellow or purple',
#   'NA',
#   'open, disturbed areas and deciduous woodlands',
#   'edible fruits'],
#  ['Distichlis spicata',
#   ' saltgrass',
#   'Poaceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '0.5 - 1.5ft; ',
#   'NA',
#   'Pod;         ',
#   'Full Sun',
#   'Clay, Loamy',
#   'Flooded, Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'tidal salt marshes, from Mean High tide above to spring tide level; high salinity; wet depressions;',
#   'often intermixed with Spartina patens; forms dense mats; tolerates salinity to 50 ppt'],
#  ['Dryopteris cristata',
#   ' crested woodfern, crested shield fern, narrow swamp fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '1.5 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'NA',
#   'evergreen',
#   'Yes',
#   'shallow emergent marsh, shrub swamp, hardwood swamp; wooded swamps or open shrubby wetlands',
#   'small rosette fronds'],
#  ['Dryopteris intermedia',
#   ' evergreen wood-fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Fern',
#   '2.5 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'NA',
#   'evergreen',
#   'Yes',
#   'rich, moist to dry woods',
#   'clump-former; not common on coastal plain; hybridizes with eight species'],
#  ['Dryopteris marginalis',
#   ' marginal shield fern, evergreen wood fern, evergreen shield fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'NA',
#   'evergreen',
#   'Yes',
#   'moist woods and clearings',
#   'clump-former; attractive; easily transplanted'],
#  ['Dulichium arundinaceum',
#   ' three-sided sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'NA',
#   'Nut/Nut-like;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, bogs, swamps, pond edges',
#   'grows best where water rarely draws down'],
#  ['Elymus canadensis',
#   ' Canada wild rye',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '2 - 6.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          October',
#   'NA',
#   'NA',
#   'dry, sandy, gravely, or rocky soil',
#   'NA'],
#  ['Elymus hystrix',
#   ' bottlebrush grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '2 - 4ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'moist, alluvial woods',
#   'NA'],
#  ['Elymus riparius',
#   ' riverbank wild-rye',
#   'Poaceae',
#   'Coastal Plain, Piedmont',
#   'DE, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'rich thickets and stream borders, alluvial flats, meadows',
#   'good for streambank conditions'],
#  ['Elymus virginicus',
#   ' Virginia wild rye',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 5.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          October',
#   'NA',
#   'NA',
#   'rich thickets and shores, meadows',
#   'tolerates a wide range of conditions; forms clumps'],
#  ['Erigeron pulchellus',
#   " robin's plantain",
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'blue, pink, white',
#   'Capsule;         ',
#   'Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          September',
#   'NA',
#   'Yes',
#   'copses, open woods and meadows, wooded slopes, roadsides',
#   'NA'],
#  ['Eupatorium dubium',
#   ' Joe-Pye weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '2 - 5ft; ',
#   'purple, rarely white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'moist, usually sandy acidic soil of swamps, bogs, marshes, swales',
#   'NA'],
#  ['Eupatorium fistulosum',
#   ' Joe-Pye weed, trumpet weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 10ft; ',
#   'pink-purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'floodplains, meadows, moist thickets, roadsides',
#   'herbal uses'],
#  ['Eupatorium hyssopifolium',
#   ' hyssop-leaved thoroughwort, hyssop-leaved eupatori',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '1 - 4.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'dry, sandy or gravelly fields roadsides, and railroad right of ways; woods, fields, salt meadows',
#   'NA'],
#  ['Eupatorium perfoliatum',
#   ' common boneset',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'floodplains, swamps, bogs, streambanks, and wet meadows',
#   'NA'],
#  ['Eupatorium purpureum',
#   ' green-stemmed Joe-Pye weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2 - 6.5ft; ',
#   'pink, purple, cream',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'open woods fields and floodplains',
#   'occurs in drier, shadier habitats than other joe-pye-weeds; injured or dried plant has vanilla scent'],
#  ['Fagus grandifolia',
#   ' American beech',
#   'Fagaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 100ft; Spread: 50 - 75ft',
#   'yellow-green',
#   'Nut/Nut-like;          orange-green',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'yellow/tan; retains leaves till spring',
#   'NA',
#   'variety of soils, moist rich uplands and lowlands',
#   'edible nuts; attractive bark; leaves may persist into winter'],
#  ['Fraxinus americana',
#   ' white ash',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 100ft; Spread: 50 - 75ft',
#   'deep purple',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'yellow, maroon',
#   'NA',
#   'moist upland slopes, valleys, coves, and bottomlands',
#   'fast growth; fall color'],
#  ['Fraxinus pennsylvanica',
#   ' green ash, red ash, swamp ash',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'purple',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'April -          May',
#   'yellow to orange',
#   'NA',
#   'tidal freshwater forested wetlands; nontidal forested wetlands; regularly flooded',
#   'tolerates drought; tolerates infrequent flooding and some salt; male and female flowers on separate plants'],
#  ['Gaultheria procumbens',
#   ' wintergreen, checkerberry',
#   'Pyrolaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '0.5 - 0.5ft; Spread: 3 - 3ft',
#   'white to pink',
#   'Berry;          red',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          August',
#   'evergreen',
#   'Yes',
#   'sandy oak woods, clearings, steep rocky open slopes, deep mesic woods, hummocks in bogs',
#   'dense, mat-like form; forms colonies; edible fruits, leaves; wintergreen taste and scent'],
#  ['Gaylussacia baccata',
#   ' black huckleberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '1.5 - 3ft; Spread: 1 - 3ft',
#   'white to pink',
#   'Berry;          black',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'reddish-purple',
#   'NA',
#   'dry to wet woods and thickets',
#   'very common; fruits edible but many-seeded'],
#  ['Gaylussacia frondosa',
#   ' dangleberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, VA',
#   'Low Shrub',
#   '2 - 4ft; Spread: 2 - 4ft',
#   'greenish to purple',
#   'Berry;          blue',
#   'Full Sun, Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist, Wet',
#   'April -          June',
#   'reddish-purple',
#   'NA',
#   'dry to wet woods and thickets',
#   'berries borne on long, drooping stems'],
#  ['Gentiana clausa',
#   ' closed gentian, bottle gentian',
#   'Gentianaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'blue',
#   'Capsule;         ',
#   'Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'moist open woods, stream banks, meadows, in noncalcareous soils',
#   'NA'],
#  ['Geranium maculatum',
#   ' wild geranium, wood geranium',
#   'Geraniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2ft; ',
#   'lavender or pink',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'woods, roadsides, & fields',
#   'adaptable plant; long bloom time; spreader; herbal uses; explosive seed capsule'],
#  ['Goodyera pubescens',
#   ' downy rattlesnake plantain',
#   'Orchidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'whitish',
#   'NA',
#   'Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'dry to moist deciduous or coniferous forests',
#   'very handsome throughout winter'],
#  ['Hamamelis virginiana',
#   ' witch hazel',
#   'Hamamelidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '15 - 30ft; Spread: 20 - 30ft',
#   'yellow',
#   'Capsule;          tan brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'September -          December',
#   'yellow',
#   'NA',
#   'woodland or brushy fields, moist or dry',
#   'noted for fall/winter bloom; medicinal uses, leaves may persist into winter'],
#  ['Helenium autumnale',
#   ' yellow sneezeweed, common sneezeweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'July -          November',
#   'NA',
#   'NA',
#   'low woods, swamps, moist riverbanks, alluvial thickets, wet meadows, marshes, ditches',
#   'tolerates wet areas; showy flowers; herbal uses'],
#  ['Helianthus angustifolius',
#   ' swamp sunflower',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '1.5 - 5.5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'swamps and moist, sandy ground',
#   'NA'],
#  ['Helianthus decapetalus',
#   ' ten-petaled sunflower, thin-leaved sunflower',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'fields, moist bottomlands, stream banks, roadsides',
#   'NA'],
#  ['Helianthus divaricatus',
#   ' woodland sunflower, rough sunflower',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Partial Sun',
#   'Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'NA',
#   'NA',
#   'dry open woods, wooded slopes, shale barrens, roadsides',
#   'NA'],
#  ['Heliopsis helianthoides',
#   ' oxeye sunflower, oxeye',
#   'Asteraceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'pale yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'June -          September',
#   'NA',
#   'NA',
#   'fields, open woods, floodplains, thickets, stream banks',
#   'long bloom time'],
#  ['Hepatica nobilis var. obtusa',
#   ' round-lobed hepatica, liverleaf',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 2ft; ',
#   'white to lavender',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'dry or rocky woods, dry upland slopes',
#   'NA'],
#  ['Heracleum maximum',
#   ' cow parsnip',
#   'Apiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '3.5 - 10ft; ',
#   'white to pink',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'May -          August',
#   'NA',
#   'NA',
# ...
#   'deciduous conifer'],
#  ['Thalictrum dioicum',
#   ' early meadow rue',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'green to purple',
#   'Capsule;         ',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'April -          May',
#   'NA',
#   'NA',
#   'rich rocky woods, ravines, alluvial terraces',
#   'NA'],
#  ['Thalictrum pubescens',
#   ' tall meadow rue',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 9ft; ',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'rich woods, low thickets, swamps, wet meadows, stream banks',
#   'foliage similar to columbines; clump-forming; delicate flowers; species very variable'],
#  ['Thalictrum thalictroides',
#   ' rue anemone, windflower',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'wooded banks and thickets',
#   'foliage similar to columbines'],
#  ['Thelypteris noveboracensis',
#   ' New York fern',
#   'Thelypteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'forested wetlands, dry to damp woods and thickets',
#   'tolerates drought; easily transplanted; forms large colonies; spreads easily'],
#  ['Thelypteris palustris',
#   ' marsh fern',
#   'Thelypteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '2 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'swamps, bogs, wet fields or thickets, fresh tidal and nontidal marshes, wooded streambanks',
#   'spreads'],
#  ['Tiarella cordifolia',
#   ' foamflower, false miterwort, heartleaf foamflower',
#   'Saxifragaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'rich woods, moist rocky wooded slopes',
#   'attractive, long-blooming; creeping, clump-forming; many cultivars'],
#  ['Tradescantia virginiana',
#   " Virginia spiderwort, widow's tears",
#   'Commelinaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'deep blue-purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'NA',
#   'wooded slopes, shale outcrops, moist fields, roadsides',
#   'flowers showy'],
#  ['Tridens flavus',
#   ' redtop, purpletop',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Grass/Grasslike',
#   '2 - 6.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'dry fields, roadsides, openings, borders of woods',
#   'NA'],
#  ['Trillium grandiflorum',
#   ' white trillium, large-flowered trillium',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'white then pink',
#   'Berry;          black',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'moist woods',
#   'showy flowers; common, often in large colonies'],
#  ['Tripsacum dactyloides',
#   ' gama grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '6 - 10ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'swales, moist fields, borders of woods, shores',
#   'excellent forage grass; often grows wild near corn fields; can hybridize with corn'],
#  ['Ulmus americana',
#   ' American elm, white elm, soft elm',
#   'Ulmaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '75 - 100ft; Spread: 75 - 100ft',
#   'red brown',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'bright yellow',
#   'NA',
#   'river bottoms, swamps, disturbed fields, road sides, cutover forests',
#   'Dutch elm disease caused decline; distinctive "vase" shape; favorite nesting site of Baltimore oriole'],
#  ['Uvularia perfoliata',
#   ' perfoliate bellwort, mealy bellwort',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 2ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'NA',
#   'moist woods',
#   'rhizome can be cooked and eaten; young shoots maybe substituted for asparagus'],
#  ['Uvularia sessilifolia',
#   ' straw lily',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'NA',
#   'Yes',
#   'dry to moist woodland',
#   'rhizomes may be cooked and eaten; young shoots may be substituted for asparagus'],
#  ['Vaccinium corymbosum',
#   ' highbush blueberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white or pink-tinged',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'April -          June',
#   'yellow to red',
#   'NA',
#   'forested wetlands, shrub swamps, bogs, upland woods; dry to wet woods, thickets, stream banks, rock outcroppings',
#   'edible berries commonly cultivated'],
#  ['Vaccinium macrocarpon',
#   ' cranberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, PA, WV',
#   'Low Shrub',
#   '0.5 - 1ft; Spread: 3 - 3ft',
#   'white to pink',
#   'Berry;          red',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Wet',
#   'June -          July',
#   'dark green to purple to red',
#   'Yes',
#   'sphagnum bogs, cool wet swampy ground',
#   'low mat form, can spread indefinitely; edible cranberries'],
#  ['Vaccinium pallidum',
#   ' early lowbush blueberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Low Shrub',
#   '1.5 - 2ft; ',
#   'white, reddish',
#   'Berry;          blue',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          May',
#   'NA',
#   'Yes',
#   'dry woods and barrens',
#   'sweet berries'],
#  ['Vaccinium stamineum',
#   ' deerberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white or purple',
#   'Berry;          bluish black',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'red',
#   'NA',
#   'dry woods, openings, barrens; dry upland oak woods, floodplain forests, clearings and thickets, pine woods and barrens, rock outcroppings',
#   'berries edible but sour'],
#  ['Veratrum viride',
#   ' green false hellebore, white hellebore',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2 - 5ft; ',
#   'yellow-green',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'May -          July',
#   'NA',
#   'NA',
#   'swamps & wet woods',
#   'leaf edges will brown if soil dries and plant is in windy area; does best in cooler temps; slugs like the foliage'],
#  ['Verbena hastata',
#   " blue vervain, simpler's joy",
#   'Verbenaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '1.5 - 5ft; ',
#   'blue to purple',
#   'Nut/Nut-like;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'moist meadows, swamps floodplains, wet ditches, roadsides',
#   'bright flowers; herbal uses'],
#  ['Verbesina alternifolia',
#   ' wingstem, yellow ironweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '3.5 - 8ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun',
#   'NA',
#   'Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'moist wooded slopes and open woodlands, riverbanks, shaded lowlands, roadsides, fields',
#   'threatened in NY'],
#  ['Vernonia noveboracensis',
#   ' New York ironweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '3.5 - 8ft; ',
#   'purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'stream banks, wet fields, fresh water marshes',
#   'brilliant flowers; tall upright form adds structure to garden; spreads'],
#  ['Viburnum acerifolium',
#   ' maple-leaved arrowwood',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 6ft; Spread: 3 - 6ft',
#   'creamy-white, pink',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist',
#   'June -          June',
#   'orange, red, purple',
#   'NA',
#   'floodplain forests, dry wooded slopes, mixed deciduous forests, talus slopes, rock outcrops, wooded ravines',
#   'dry, edible berries'],
#  ['Viburnum dentatum',
#   ' southern arrowwood',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub, Tall Shrub',
#   '10 - 15ft; Spread: 6 - 12ft',
#   'white',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'reddish-purple',
#   'NA',
#   'swamps and wet woods, bogs, floodplain forests, stream banks; low, wet acid-sand habitats',
#   'stems very straight, nice structure in winter'],
#  ['Viburnum nudum',
#   ' naked witherod, possum-haw viburnum',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA',
#   'Medium Shrub',
#   '6.5 - 20ft; Spread: 12 - 20ft',
#   'white to cream',
#   'Berry;          red to blue, then black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'June -          July',
#   'red to purple',
#   'NA',
#   'wet woods, swamps, margins of vernal ponds, heath bogs, deep rich upland forests, creek bottoms, wet sandy woods',
#   'edible fruit but very acidic; shallow fibrous roots, transplants well'],
#  ['Viburnum nudum var. cassinoides',
#   ' witherod',
#   'Adoxaceae, Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'MD, PA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'creamy white',
#   'Berry;          pink to blue-black',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'orange-red to purple',
#   'NA',
#   'swamps, bogs, moist woods, and barrens',
#   'handsome stature; multiple fruit colors at once'],
#  ['Viburnum prunifolium',
#   ' black haw',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '12 - 24ft; Spread: 8 - 12ft',
#   'white',
#   'Berry;          pink to bluish-black',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'April -          May',
#   'reddish purple',
#   'NA',
#   'successional woods, thickets, old fields, and roadsides',
#   'fruits edible, used for preserves'],
#  ['Viola conspersa',
#   ' American dog violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'pale blue, violet',
#   'Capsule;          green',
#   'Full Sun, Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'April -          July',
#   'NA',
#   'Yes',
#   'moist woods, damp fields, swamps',
#   'delicate plant and flower; edible'],
#  ['Viola cucullata',
#   ' marsh blue violet, blue marsh violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, PA, VA, WV',
#   'Herbaceous',
#   'NA',
#   'pale purple',
#   'Capsule;          green',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          July',
#   'NA',
#   'Yes',
#   'bogs, meadows, & swamps',
#   'stemless; self-sows; can become a nuisance'],
#  ['Viola pedata',
#   " bird's foot violet",
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Herbaceous',
#   'NA',
#   'pale blue or w/ purple-black tips',
#   'Capsule;          green',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'sandy or rocky barrens, dry forested slopes',
#   'stemless'],
#  ['Viola sororia',
#   ' common blue violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'dark blue, violet',
#   'Capsule;          green with purple',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist',
#   'March -          June',
#   'NA',
#   'NA',
#   'dry to moist woods, swamps, thickets',
#   'delicate plant and flower; edible; spreader; stemless'],
#  ['Viola striata',
#   ' striped cream violet, striped violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'ivory w/ purple',
#   'Capsule;          green',
#   'Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'April -          June',
#   'NA',
#   'NA',
#   'alluvial woods, alkaline swamps, moist fields',
#   'NA'],
#  ['Wisteria frutescens',
#   ' Atlantic wisteria, American wisteria',
#   'Fabaceae',
#   'Coastal Plain',
#   'DE, VA',
#   'Vine',
#   '20 - 20ft; ',
#   'lilac',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          August',
#   'NA',
#   'NA',
#   'borders of wooded swamps and wet woodlands, stream banks, moist or wet thickets',
#   'NA'],
#  ['Woodwardia areolata',
#   ' netted chain fern',
#   'Blechnaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '0.5 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'mostly acid bogs, swamps, or wet woods',
#   'spreads by creeping rhizome'],
#  ['Woodwardia virginica',
#   ' Virginia chain fern',
#   'Blechnaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '3 - 6ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'swampy places, wet woods',
#   'spreads by creeping rhizome'],
#  ['Yucca filamentosa',
#   " Adam's needle",
#   'Agavaceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '2 - 2.5ft; ',
#   'white',
#   'NA',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'June -          September',
#   'NA',
#   'NA',
#   'coastal sand dunes; outcroppings on thin rocky soils',
#   'flower stalk can rise 5-15 feet above foliage'],
#  ['Zizania aquatica',
#   ' wild rice',
#   'Poaceae',
#   'Coastal Plain',
#   'DE, DC, MD, NY, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '6 - 10ft; ',
#   'NA',
#   'Achene (dry, flat seed);         ',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'June -          September',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, stream borders, shallow waters',
#   'annual; edible'],
#  ['Zizia aurea',
#   ' golden-alexanders',
#   'Apiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'wooded bottomland, stream banks, moist meadows, floodplain',
#   'NA']]

# %%
# Store the list as a file for now
import json

with open("plant_infofile_v2.txt","w") as f:
    json.dump(plant_info, f)

# %%
# Can check out the file created above by running the following

with open("plant_infofile_v2.txt","r") as f:
    plant_list = json.load(f)
    
plant_list
# Out:
# [['Binomial',
#   'Common Names',
#   'Family',
#   'Regions',
#   'States',
#   'Plant Types',
#   'Height',
#   'Flower Color',
#   'Fruit',
#   'Sun Exposure',
#   'Soil Texture',
#   'Soil Moisture',
#   'Blooms',
#   'Fall Color',
#   'Ground Cover',
#   'Habitat',
#   'Notes'],
#  ['Acer negundo',
#   ' box elder, ash leaf maple, Manitoba maple',
#   'Aceraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '30 - 60ft; Spread: 30 - 60ft',
#   'yellow-green',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow, red',
#   'NA',
#   'grows best in lowland sites along rivers, streams, ponds, and seasonally flooded areas; tolerates a variety of soil types',
#   'brittle wood; thicket-forming'],
#  ['Acer rubrum',
#   ' red maple, scarlet maple, swamp maple, soft maple',
#   'Aceraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '40 - 100ft; Spread: 30 - 75ft',
#   '(inconspicuous)',
#   'Winged;          red-brown or yellow',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'red, orange, yellow',
#   'NA',
#   'swamps, uplands;  occasionally on dry rocky hillsides and sanddunes',
#   'earliest spring bloomer; adaptable'],
#  ['Actaea pachypoda',
#   " doll's eyes",
#   'Ranunculaceae',
#   'Coastal Plain',
#   'DE, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'whitish',
#   'Berry;          white or red',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'rich open woods, thickets',
#   'interesting berries; infrequent in Piedmont and mountain regions'],
#  ['Adiantum pedatum',
#   ' northern maidenhair fern',
#   'Pteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Fern',
#   '1 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'rich, moist woods; rocky well-shaded habitats, protected from dryness or direct sunlight',
#   'grows in clumps; delicate texture; herbal uses'],
#  ['Agalinis purpurea',
#   ' purple false foxglove',
#   'Scrophulariaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '1 - 4ft; ',
#   'rose-purple, white',
#   'Capsule;         ',
#   'Full Sun',
#   'Sandy',
#   'Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'moist sandy fields, rocky shores, serpentine barrens',
#   'NA'],
#  ['Ageratina altissima var. altissima',
#   ' white snakeroot',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'rich woods, thickets, clearings, meadows',
#   'tough plant; cultivars available; prefers basic soils'],
#  ['Agrostis perennans',
#   ' autumn bentgrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, PA, VA, WV',
#   'Grass/Grasslike',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'dry or moist thickets, open woods, unshaded areas',
#   'NA'],
#  ['Alnus serrulata',
#   ' smooth alder, hazel alder',
#   'Betulaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Shrub',
#   '12 - 20ft; Spread: 12 - 20ft',
#   'purple',
#   'Cone/Cone-like;          brown',
#   'Full Sun',
#   'Clay, Loamy',
#   'Flooded, Moist, Wet',
#   'March -          April',
#   'yellow, red',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands',
#   'forms thickets along watercourses; nitrogen fixing; tolerates flooding to 3"'],
#  ['Amelanchier canadensis',
#   ' serviceberry, shadbush, shadblow serviceberry, Canadian serviceberry',
#   'Rosaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA',
#   'Small/Medium Tree (Understory)',
#   '35 - 50ft; Spread: 35 - 50ft',
#   'white',
#   'Fleshy;          red to purple',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'orange to red',
#   'NA',
#   'swamps, low ground, woods, & thickets',
#   'NA'],
#  ['Ammophila breviligulata',
#   ' dunegrass, American beachgrass',
#   'Poaceae',
#   'Coastal Plain',
#   'VA',
#   'Grass/Grasslike',
#   '1.5 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'maritime beach/dunes, maritime grassland, maritime shrubland',
#   'prefers well-drained, sandy sites; spreads rapidly by rhizomes'],
#  ['Andropogon glomeratus',
#   ' bushy bluestem',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1.5 - 5ft; ',
#   'reddish brown',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'August -          October',
#   'reddish',
#   'NA',
#   'fresh marshes, wet soils, coastal areas',
#   'tolerates drought; grows in tufts; reddish fall color'],
#  ['Andropogon virginicus',
#   ' broomsedge',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3ft; ',
#   'reddish brown',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'August -          November',
#   'reddish-tan',
#   'NA',
#   'wet meadows, transition areas; poor soils',
#   'wildlife food and cover; tolerates drought; grows in tufts; reddish-tan fall color'],
#  ['Aquilegia canadensis',
#   ' eastern or wild columbine',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 3ft; ',
#   'red-yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'rich rocky woods and slopes, cliffs, ledges, pastures, and roadside banks; rarely in swamps',
#   'commonly cultivated; spreads by seed'],
#  ['Aralia nudicaulis',
#   ' wild sarsaparilla',
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'white or green',
#   'Berry;          purple-black',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'NA',
#   'dry to moist woods',
#   'aromatic; single-leaved; lacks an above-ground stem; not common in coastal plain'],
#  ['Aralia racemosa',
#   ' spikenard',
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'greenish-white',
#   'Berry;          dark purple',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'rich woods and thickets, wooded slopes and edges',
#   'not common in coastal plain'],
#  ['Aralia spinosa',
#   " Devil's walking stick",
#   'Araliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Tall Shrub',
#   '20 - 30ft; Spread: 12 - 20ft',
#   'white',
#   'Berry;          black',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          August',
#   'yellow',
#   'NA',
#   'moist woods, stream banks, roadsides',
#   'seeds are poisonous if chewed; low maintenance; spreads from new shoots; thorny, clublike stem'],
#  ['Arisaema triphyllum',
#   ' Jack-in-the-pulpit',
#   'Araceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'striped, purple or green',
#   'Berry;         ',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'March -          June',
#   'NA',
#   'NA',
#   'wet woods, bogs and swamps',
#   'red berry clusters appear late summer to fall; unusual flower; spreads rapidly from seed'],
#  ['Asarum canadense',
#   ' wild ginger',
#   'Aristolochiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'brownish-purple',
#   'Capsule;          brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'semi-evergreen',
#   'Yes',
#   'rich woodlands, less so on acid soils',
#   'flower inconspicuous; attractive leaves; will spread; semi-evergreen'],
#  ['Asclepias incarnata',
#   ' swamp milkweed',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '4 - 6ft; ',
#   'pink to reddish',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'May -          June',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, wet meadows, shrub swamps, clearings of wet woods, shores and ditches',
#   'can tolerate drought; interesting seed pod'],
#  ['Asclepias syriaca',
#   ' common milkweed',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '3.5 - 6.5ft; ',
#   'pale purple',
#   'Pod;         ',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'May -          August',
#   'NA',
#   'NA',
#   'thickets, roadsides, dry fields',
#   'interesting seed pods; fragrant flower'],
#  ['Asclepias tuberosa',
#   ' butterflyweed, butterfly milkweed, butterfly flower',
#   'Asclepiadaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'orange',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'NA',
#   'dry fields, roadsides and shale barrens',
#   'taproot does not transplant well but seedlings do; attractive seed pod'],
#  ['Asimina triloba',
#   ' paw-paw',
#   'Annonaceae',
#   'Coastal Plain',
#   'DE, DC, MD, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'purple',
#   'Berry;          yellow',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'April -          June',
#   'yellow/copper-red',
#   'NA',
#   'deep, rich, moist soils of river valleys and bottomlands.  Also in the understory of hardwood forests.',
#   'NA'],
#  ['Asplenium platyneuron',
#   ' ebony spleenwort',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, VA, WV',
#   'Fern',
#   '0.5 - 1.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'NA',
#   'evergreen',
#   'Yes',
#   'sandy or clayey banks, open woods and thickets, slopes, rocky ledges, swamps',
#   'easily transplanted; only moderate care needed; evergreen'],
#  ['Athyrium filix-femina',
#   ' northern lady fern',
#   'Dryopteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Partial Sun',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'wet woods, moist banks, wooded hillsides, sandy bogs',
#   'varieties occur throughout region; in MD, VA can also use subspecies asplenioides (southern lady fern)'],
#  ['Baccharis halimifolia',
#   ' high-tide bush, groundsel tree, sea myrtle',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, MD, VA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white',
#   'Achene (dry, flat seed);          silvery white',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'August -          September',
#   'purple',
#   'NA',
#   'salt or brackish marshes, fresh tidal marshes and ditches, shores, dunes',
#   'volunteers in disturbed places; shallow, lateral roots; tolerates flooding to 6"; tolerates salinity to 15 ppt'],
#  ['Baptisia tinctoria',
#   ' yellow wild indigo',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'May -          September',
#   'NA',
#   'NA',
#   'dry open woods and clearings, sandy acidic soil',
#   'tolerates poor soils'],
#  ['Betula nigra',
#   ' river birch, red birch, black birch',
#   'Betulaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'dark brown',
#   'Cone/Cone-like;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'lowland species mainly along streams, rivers, ponds, and swamps',
#   'attractive peeling bark;'],
#  ['Bidens cernua',
#   ' nodding beggar-ticks, nodding bur marigold',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '0.5 - 3ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'tidal marsh, sloughs, springs, pools, shore',
#   'NA'],
#  ['Bignonia capreolata',
#   ' crossvine',
#   'Bignoniaceae',
#   'Coastal Plain',
#   'MD, VA',
#   'Vine',
#   '30 - 45ft; Spread: 20 - 35ft',
#   'orange with red',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'semi-evergreen; reddish-purple',
#   'Yes',
#   'alluvial woods, swampy forests, calcareous soils on river banks, cliffs in ravines, dry open woods, bogs, fence rows, rock outcrops',
#   'spreads across ground and climbs any structure it meets (control by cutting); semi-evergreen'],
#  ['Boltonia asteroides',
#   " star boltonia, white doll's daisy",
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, VA, WV',
#   'Herbaceous',
#   '0.5 - 2.5ft; ',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'gravelly shores, sandy thickets',
#   'NA'],
#  ['Botrychium virginianum',
#   ' rattlesnake fern',
#   'Ophioglossaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'rich, well-drained, wooded areas',
#   'NA'],
#  ['Callicarpa americana',
#   ' American beautyberry, French mulberry',
#   'Verbenaceae',
#   'Coastal Plain',
#   'DC, VA',
#   'Medium Shrub',
#   '6 - 6ft; Spread: 6 - 6ft',
#   'lavender-pink',
#   'Berry;          lavender',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'in most soils',
#   'flowers from new growth; if overgrown prune to 6-18" tall; will regain height in one season'],
#  ['Caltha palustris',
#   ' marsh marigold',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '1 - 2ft; ',
#   'bright yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Flooded, Wet',
#   'April -          June',
#   'NA',
#   'NA',
#   'forested wetlands, shrub swamps, streambanks, seeps, wet meadows',
#   'clump-forming; needs some periods of drier soil; tolerates flooding to 6"'],
#  ['Campsis radicans',
#   ' trumpet vine, trumpet creeper',
#   'Bignoniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA',
#   'Vine',
#   '30 - 30ft; Spread: 20 - 35ft',
#   'orange',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'yellow green',
#   'Yes',
#   'moist woodlands, fence rows, roadside thickets, floodplain forests, rock hillsides, open woods, stream banks, old fields',
#   'thick, twisted, aged woody vines; leaves/flowers may cause dermatitis (skin irritation)'],
#  ['Carex crinita var. crinita',
#   ' long hair sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'swales, damp thickets, and low woods',
#   'NA'],
#  ['Carex glaucodea',
#   ' blue wood sedge',
#   'Cyperaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Grass/Grasslike',
#   '0.5 - 2ft; ',
#   'brown to reddish',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'Yes',
#   'moist to dry woods and fields',
#   'clump-forming; alternative to Liriope'],
#  ['Carex lurida',
#   ' sallow sedge, lurid sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'swales, swamps, and wet woods',
#   'wetland plant; interesting seeds'],
#  ['Carex pensylvanica',
#   ' Pennsylvania sedge',
#   'Cyperaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 1.5ft; ',
#   'reddish to white',
#   'NA',
#   'Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'open dry soil or open woods; dry or sandy, open or rocky oak woods, wooded slopes; clump-forming',
#   'alternative to lawn; plant densely; fine textured leaves <6"'],
#  ['Carex stricta',
#   ' tussock sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'reddish to purple brown',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'May -          August',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands, wet swales, moist fields',
#   'grows in clumps; partly persists in winter; tolerates flooding to 6"'],
#  ['Carex vulpinoidea',
#   ' fox sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '0.5 - 3.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Flooded, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'shallow emergent marsh, shrub swamp, floodplain forest, hardwood swamp',
#   'grows in clumps; tolerates saturation and flooding to 6"'],
#  ['Carya alba',
#   ' mockernut hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 35 - 50ft',
#   'light green',
#   'Nut/Nut-like;          light reddish brown',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'NA',
#   'ridges, dry hills, and hillsides; rich well drained soils',
#   'good fall color'],
#  ['Carya cordiformis',
#   ' bitternut hickory, swamp hickory, pignut, bitternut',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 60 - 100ft',
#   'yellow-green',
#   'Nut/Nut-like;          yellowish green',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'can grow in swamps and frequently flooded areas and dry hillsides; does best in rich bottomlands',
#   'NA'],
#  ['Carya glabra',
#   ' pignut hickory, sweet pignut hickory, smooth bark hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '60 - 100ft; Spread: 35 - 50ft',
#   'yellow-green',
#   'Nut/Nut-like;          dark brown',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'dry woods, primarily on hillsides and along dry ridges; does best in deep, moist, well drained soils',
#   'NA'],
#  ['Carya ovata',
#   ' shagbark hickory, scalybark hickory, shellbark hickory',
#   'Juglandaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '70 - 100ft; Spread: 35 - 50ft',
#   'yellow-green',
#   'Nut/Nut-like;          dark or reddish brown',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'May -          June',
#   'brown',
#   'NA',
#   'both dry upland slopes to 2,000 feet, and deep well-drained soils in lowlands and valleys',
#   'attractive peeling bark'],
#  ['Castanea pumila',
#   ' chinquapin, chinkapin, eastern chinkapin, Allegany chinkapin',
#   'Fagaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '12 - 20ft; Spread: 12 - 20ft',
#   'pale yellow',
#   'Nut/Nut-like;          dark brown',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'June -          June',
#   'yellow or purple',
#   'NA',
#   'dry rocky slopes, dry woods, steep rocky land, rocky stream banks, sandy ridges, borders of swamps, open woods',
#   'sweet, edible fruit'],
#  ['Caulophyllum thalictroides',
#   ' blue cohosh',
#   'Berberidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'green-yellow, green-purple',
#   'Berry;          dark blue',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'moist rich woods',
#   'NA'],
#  ['Ceanothus americanus',
#   ' New Jersey tea',
#   'Rhamnaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 3ft; Spread: 3 - 6ft',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry',
#   'May -          September',
#   'yellow to tan',
#   'NA',
#   'meadow, old field, glade, forest; dry open woods and borders, rocky areas, openings',
#   'tough; tolerates moist soil if well drained; fixes nitrogen; tolerates dryness'],
#  ['Celastrus scandens',
#   ' American bittersweet',
#   'Celastraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Vine',
#   '3 - 35ft; Spread: 6 - 20ft',
#   'greenish',
#   'Capsule;          orange and red',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'Yes',
#   'roadsides, woods edge, fence rows, old pastures, hedges, rocky streams, bluffs, rocky slopes, dunes, sandy oak woods',
#   'distinguished from nonnative invasive Oriental bittersweet by flowers/fruits in clusters at ends of twigs'],
#  ['Celtis occidentalis',
#   ' common hackberry, sugarberry, nettletree',
#   'Ulmaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '40 - 100ft; Spread: 40 - 100ft',
#   'yellow green, brown tint',
#   'Berry;          purple brown',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'April -          May',
#   'yellow',
#   'NA',
#   'drainage basins, mature floodplains, wooded slopes or high rocky limestone bluffs bordering streams, windbreaks',
#   'butterfly larval host; drought tolerant; tolerates occasional flooding; saplings can sprout in deep shade, common on limestone soils'],
#  ['Cephalanthus occidentalis',
#   ' buttonbush',
#   'Rubiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 12 - 20ft',
#   'creamy white',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'July -          August',
#   'yellow-green',
#   'NA',
#   'fresh tidal and nontidal marshes, shrub swamps, forested wetlands, borders of streams, lakes, and ponds',
#   'needs sun to flower; flowers fragrant; interesting fruit; tolerates drought; leaves may persist into winter; tolerates flooding to 36"'],
#  ['Cercis canadensis',
#   ' eastern redbud',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'pink to lavender',
#   'Pod;          black',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          May',
#   'golden yellow',
#   'NA',
#   'rich, moist sites; prefers river bottoms and stream banks',
#   'purple flowers in spring, about same time as flowering dogwood; fixes nitrogen'],
#  ['Chamaecrista fasciculata',
#   ' partridge pea, prairie senna',
#   'Caesalpiniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 3ft; ',
#   'yellow',
#   'Pod;         ',
#   'Full Sun',
#   'Sandy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'upland meadows, sandy fields, stream banks',
#   'pods coil after split open; spreads'],
#  ['Chamaecyparis thyoides',
#   ' Atlantic white cedar',
#   'Cupressaceae',
#   'Coastal Plain',
#   'DE, MD, VA',
#   'Tall Tree (Canopy)',
#   '75 - 75ft; ',
#   'greenish brown',
#   'Cone/Cone-like;          bluish',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'evergreen',
#   'NA',
#   'freshwater swamps or wet woods; best in acid-peat beds',
#   'NA'],
#  ['Chasmanthium latifolium',
#   ' wild oats, river oats, sea oats, spanglegrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '2 - 5ft; ',
#   'green then tan',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'NA',
#   'NA',
#   'streambank and alluvial woods',
#   'NA'],
#  ['Chelone glabra',
#   ' white turtlehead, turtlehead',
#   'Scrophulariaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'wet woods, stream banks, swamps, wet thickets',
#   'strong grower; herbal uses; host for Baltimore checkerspot butterfly'],
#  ['Chimaphila maculata',
#   " striped wintergreen, striped prince's pine",
#   'Pyrolaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry',
#   'June -          August',
#   'NA',
#   'Yes',
#   'acid, dry woods, frequently under pines',
#   'flowers fragrant'],
#  ['Chionanthus virginicus',
#   ' white fringetree',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'white',
#   'Berry;          bluish black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'yellow',
#   'NA',
#   'moist streambanks, ridges, and hillsides in sandy to deep-rich soils',
#   'NA'],
#  ['Chrysogonum virginianum',
#   ' green-and-gold, golden knees',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'open woods on limestone, rocky open woodland',
#   'will bloom longer if kept moist'],
#  ['Chrysopsis mariana',
#   ' golden aster, Maryland golden aster',
#   'Asteraceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '0.5 - 2.5ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry',
#   'July -          October',
#   'NA',
#   'Yes',
#   'dry sandy or argillaceous or rocky woods and openings, roadsides, serpentine barrens',
#   'NA'],
#  ['Cimicifuga racemosa',
#   ' black snakeroot, black cohosh, fairy candles',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2.5 - 8.5ft; ',
#   'white',
#   'Pod;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'June -          September',
#   'NA',
#   'NA',
#   'rich woods, wooded slopes, ravines, thickets',
#   'NA'],
#  ['Claytonia virginica',
#   ' narrowleaf spring beauty, spring beauty',
#   'Portulacaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white with pink',
#   'Capsule;         ',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'March -          May',
#   'NA',
#   'NA',
#   'rich woods, thickets and clearings, alluvial soils',
#   'NA'],
#  ['Clematis virginiana',
#   " virgin's bower",
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Vine',
#   '6 - 20ft; Spread: 6 - 12ft',
#   'white',
#   'Achene (dry, flat seed);          brown',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'yellow, green or purplish',
#   'NA',
#   'fencerows and thickets, riverbanks, low calcareous thickets, woods edge, roadside swales, swamps, overhanging cliffs',
#   'fragrant flowers; feathery seeds; young plants can be transplanted;yellow, green or purplish fall color'],
#  ['Clethra alnifolia',
#   ' sweet pepperbush, summersweet',
#   'Clethraceae',
#   'Coastal Plain',
#   'DE, DC, MD, NY, VA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 3 - 6ft',
#   'white/ pink',
#   'Capsule;          brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          August',
#   'yellow',
#   'NA',
#   'tidal and nontidal forested wetlands, shrub swamps, bogs, sandy woods, coastal river floodplains, lakeshores',
#   'very fragrant; tolerates some flooding by partly salty water'],
#  ['Clitoria mariana',
#   ' Maryland butterfly pea',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Herbaceous, Vine',
#   '6 - 6ft; ',
#   'pale blue or pinkish',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry',
#   'June -          September',
#   'NA',
#   'NA',
#   'dry, open areas on sandy soils',
#   'vine-like'],
#  ['Comptonia peregrina',
#   ' sweetfern',
#   'Myricacea',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 3ft; Spread: 3 - 6ft',
#   'yellow-green',
#   'Cone/Cone-like;          green to brown',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'April -          May',
#   'brown',
#   'NA',
#   'hillsides or dry cliffs, woods openings, sand flats and barrens, old fields, dunes',
#   'fragrant; fixes nitrogen, leaves may persist into winter'],
#  ['Conoclinium coelestinum',
#   ' mistflower, wild ageratum',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'blue, violet or purple',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'old fields, meadows; dry, sandy woodlands and clearings; damp thickets; stream banks',
#   'NA'],
#  ['Coreopsis tripteris',
#   ' tall coreopsis, tall tickseed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, VA, WV',
#   'Herbaceous',
#   '3.5 - 10ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          September',
#   'NA',
#   'NA',
#   'thickets, old fields, wood borders, roadsides',
#   'flower has anise scent'],
#  ['Cornus amomum',
#   ' silky dogwood, red willow, silky cornel',
#   'Cornaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white',
#   'Berry;          blue',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'May -          June',
#   'orange, red or purple',
#   'NA',
#   'forested seasonal wetlands and floodplains, shrub wetlands, stream and pond banks, clearings',
#   'NA'],
#  ['Cornus florida',
#   ' flowering dogwood',
#   'Cornaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 50ft; Spread: 20 - 50ft',
#   'white',
#   'Berry;          red to orange',
#   'Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          May',
#   'scarlet red',
#   'NA',
#   'woodland edges and openings; hardwood and mixed coniferous forests, mountain slopes, and coves',
#   'fall migrant birds eat berries; tolerates sun, best in moist, well-drained, acidic soil with organic matter, VA state tree'],
#  ['Crataegus crus-galli',
#   ' cockspur hawthorn',
#   'Rosaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; Spread: 20 - 35ft',
#   'white',
#   'Fleshy;          dull red or green',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'orange to red',
#   'NA',
#   'thickets and open ground, especially in dry or rocky places; slopes of low hills in rich soils',
#   'NA'],
#  ['Crataegus viridis',
#   ' southern thorn, green hawthorn',
#   'Rosaceae',
#   'Coastal Plain',
#   'DE, MD, NY, VA',
#   'Small/Medium Tree (Understory)',
#   '20 - 35ft; ',
#   'white',
#   'Fleshy;          bright red to orange',
#   'Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'April -          April',
#   'purple, scarlet',
#   'NA',
#   'moist soils in lowlands and valleys',
#   'NA'],
#  ['Danthonia spicata',
#   ' poverty oatgrass, poverty grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 2ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist',
#   'May -          July',
#   'NA',
#   'Yes',
#   'open woods, old pastures, and meadows',
#   'NA'],
#  ['Dennstaedtia punctilobula',
#   ' hay-scented fern',
#   'Dennstaedtiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'NA',
#   'NA',
#   'Yes',
#   'open woods and fields',
#   'can spread over large areas of open understory or pasture'],
#  ['Desmodium paniculatum',
#   ' panicled or narrow-leaf tick-trefoil',
#   'Fabaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'purplish or green',
#   'Pod;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry',
#   'July -          September',
#   'NA',
#   'NA',
#   'clearings and borders of moist or dry woods',
#   'not found near coast'],
#  ['Dichanthelium clandestinum',
#   ' deer-tongue',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '2 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          October',
#   'NA',
#   'NA',
#   'moist woods, along roadsides',
#   'NA'],
#  ['Dichanthelium commutatum',
#   ' variable panicgrass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '1 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          October',
#   'NA',
#   'NA',
#   'rocky or sandy woods',
#   'NA'],
#  ['Diospyros virginiana',
#   ' common persimmon',
#   'Ebenaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'greenish yellow to cream',
#   'Berry;          orange purple',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry, Moist',
#   'June -          June',
#   'yellow or purple',
#   'NA',
#   'open, disturbed areas and deciduous woodlands',
#   'edible fruits'],
#  ['Distichlis spicata',
#   ' saltgrass',
#   'Poaceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '0.5 - 1.5ft; ',
#   'NA',
#   'Pod;         ',
#   'Full Sun',
#   'Clay, Loamy',
#   'Flooded, Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'tidal salt marshes, from Mean High tide above to spring tide level; high salinity; wet depressions;',
#   'often intermixed with Spartina patens; forms dense mats; tolerates salinity to 50 ppt'],
#  ['Dryopteris cristata',
#   ' crested woodfern, crested shield fern, narrow swamp fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '1.5 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'NA',
#   'evergreen',
#   'Yes',
#   'shallow emergent marsh, shrub swamp, hardwood swamp; wooded swamps or open shrubby wetlands',
#   'small rosette fronds'],
#  ['Dryopteris intermedia',
#   ' evergreen wood-fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Fern',
#   '2.5 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'NA',
#   'evergreen',
#   'Yes',
#   'rich, moist to dry woods',
#   'clump-former; not common on coastal plain; hybridizes with eight species'],
#  ['Dryopteris marginalis',
#   ' marginal shield fern, evergreen wood fern, evergreen shield fern',
#   'Aspleniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Fern',
#   '1 - 3ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'NA',
#   'evergreen',
#   'Yes',
#   'moist woods and clearings',
#   'clump-former; attractive; easily transplanted'],
#  ['Dulichium arundinaceum',
#   ' three-sided sedge',
#   'Cyperaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 3.5ft; ',
#   'NA',
#   'Nut/Nut-like;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, bogs, swamps, pond edges',
#   'grows best where water rarely draws down'],
#  ['Elymus canadensis',
#   ' Canada wild rye',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '2 - 6.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          October',
#   'NA',
#   'NA',
#   'dry, sandy, gravely, or rocky soil',
#   'NA'],
#  ['Elymus hystrix',
#   ' bottlebrush grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Grass/Grasslike',
#   '2 - 4ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'moist, alluvial woods',
#   'NA'],
#  ['Elymus riparius',
#   ' riverbank wild-rye',
#   'Poaceae',
#   'Coastal Plain, Piedmont',
#   'DE, PA, VA, WV',
#   'Grass/Grasslike',
#   '0.5 - 5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'July -          September',
#   'NA',
#   'NA',
#   'rich thickets and stream borders, alluvial flats, meadows',
#   'good for streambank conditions'],
#  ['Elymus virginicus',
#   ' Virginia wild rye',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '1 - 5.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          October',
#   'NA',
#   'NA',
#   'rich thickets and shores, meadows',
#   'tolerates a wide range of conditions; forms clumps'],
#  ['Erigeron pulchellus',
#   " robin's plantain",
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'blue, pink, white',
#   'Capsule;         ',
#   'Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          September',
#   'NA',
#   'Yes',
#   'copses, open woods and meadows, wooded slopes, roadsides',
#   'NA'],
#  ['Eupatorium dubium',
#   ' Joe-Pye weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '2 - 5ft; ',
#   'purple, rarely white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'moist, usually sandy acidic soil of swamps, bogs, marshes, swales',
#   'NA'],
#  ['Eupatorium fistulosum',
#   ' Joe-Pye weed, trumpet weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 10ft; ',
#   'pink-purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'floodplains, meadows, moist thickets, roadsides',
#   'herbal uses'],
#  ['Eupatorium hyssopifolium',
#   ' hyssop-leaved thoroughwort, hyssop-leaved eupatori',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '1 - 4.5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'dry, sandy or gravelly fields roadsides, and railroad right of ways; woods, fields, salt meadows',
#   'NA'],
#  ['Eupatorium perfoliatum',
#   ' common boneset',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'July -          October',
#   'NA',
#   'NA',
#   'floodplains, swamps, bogs, streambanks, and wet meadows',
#   'NA'],
#  ['Eupatorium purpureum',
#   ' green-stemmed Joe-Pye weed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2 - 6.5ft; ',
#   'pink, purple, cream',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'open woods fields and floodplains',
#   'occurs in drier, shadier habitats than other joe-pye-weeds; injured or dried plant has vanilla scent'],
#  ['Fagus grandifolia',
#   ' American beech',
#   'Fagaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 100ft; Spread: 50 - 75ft',
#   'yellow-green',
#   'Nut/Nut-like;          orange-green',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'yellow/tan; retains leaves till spring',
#   'NA',
#   'variety of soils, moist rich uplands and lowlands',
#   'edible nuts; attractive bark; leaves may persist into winter'],
#  ['Fraxinus americana',
#   ' white ash',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 100ft; Spread: 50 - 75ft',
#   'deep purple',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'April -          May',
#   'yellow, maroon',
#   'NA',
#   'moist upland slopes, valleys, coves, and bottomlands',
#   'fast growth; fall color'],
#  ['Fraxinus pennsylvanica',
#   ' green ash, red ash, swamp ash',
#   'Oleaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '50 - 75ft; Spread: 35 - 50ft',
#   'purple',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Flooded, Moist, Wet',
#   'April -          May',
#   'yellow to orange',
#   'NA',
#   'tidal freshwater forested wetlands; nontidal forested wetlands; regularly flooded',
#   'tolerates drought; tolerates infrequent flooding and some salt; male and female flowers on separate plants'],
#  ['Gaultheria procumbens',
#   ' wintergreen, checkerberry',
#   'Pyrolaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '0.5 - 0.5ft; Spread: 3 - 3ft',
#   'white to pink',
#   'Berry;          red',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          August',
#   'evergreen',
#   'Yes',
#   'sandy oak woods, clearings, steep rocky open slopes, deep mesic woods, hummocks in bogs',
#   'dense, mat-like form; forms colonies; edible fruits, leaves; wintergreen taste and scent'],
#  ['Gaylussacia baccata',
#   ' black huckleberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '1.5 - 3ft; Spread: 1 - 3ft',
#   'white to pink',
#   'Berry;          black',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'reddish-purple',
#   'NA',
#   'dry to wet woods and thickets',
#   'very common; fruits edible but many-seeded'],
#  ['Gaylussacia frondosa',
#   ' dangleberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, VA',
#   'Low Shrub',
#   '2 - 4ft; Spread: 2 - 4ft',
#   'greenish to purple',
#   'Berry;          blue',
#   'Full Sun, Partial Sun, Shade',
#   'Sandy',
#   'Dry, Moist, Wet',
#   'April -          June',
#   'reddish-purple',
#   'NA',
#   'dry to wet woods and thickets',
#   'berries borne on long, drooping stems'],
#  ['Gentiana clausa',
#   ' closed gentian, bottle gentian',
#   'Gentianaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 3.5ft; ',
#   'blue',
#   'Capsule;         ',
#   'Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'moist open woods, stream banks, meadows, in noncalcareous soils',
#   'NA'],
#  ['Geranium maculatum',
#   ' wild geranium, wood geranium',
#   'Geraniaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2ft; ',
#   'lavender or pink',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'woods, roadsides, & fields',
#   'adaptable plant; long bloom time; spreader; herbal uses; explosive seed capsule'],
#  ['Goodyera pubescens',
#   ' downy rattlesnake plantain',
#   'Orchidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'whitish',
#   'NA',
#   'Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'June -          August',
#   'NA',
#   'NA',
#   'dry to moist deciduous or coniferous forests',
#   'very handsome throughout winter'],
#  ['Hamamelis virginiana',
#   ' witch hazel',
#   'Hamamelidaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '15 - 30ft; Spread: 20 - 30ft',
#   'yellow',
#   'Capsule;          tan brown',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'September -          December',
#   'yellow',
#   'NA',
#   'woodland or brushy fields, moist or dry',
#   'noted for fall/winter bloom; medicinal uses, leaves may persist into winter'],
#  ['Helenium autumnale',
#   ' yellow sneezeweed, common sneezeweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist',
#   'July -          November',
#   'NA',
#   'NA',
#   'low woods, swamps, moist riverbanks, alluvial thickets, wet meadows, marshes, ditches',
#   'tolerates wet areas; showy flowers; herbal uses'],
#  ['Helianthus angustifolius',
#   ' swamp sunflower',
#   'Asteraceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '1.5 - 5.5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'swamps and moist, sandy ground',
#   'NA'],
#  ['Helianthus decapetalus',
#   ' ten-petaled sunflower, thin-leaved sunflower',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Sandy',
#   'Moist',
#   'July -          October',
#   'NA',
#   'NA',
#   'fields, moist bottomlands, stream banks, roadsides',
#   'NA'],
#  ['Helianthus divaricatus',
#   ' woodland sunflower, rough sunflower',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 6.5ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Partial Sun',
#   'Sandy',
#   'Dry, Moist',
#   'July -          September',
#   'NA',
#   'NA',
#   'dry open woods, wooded slopes, shale barrens, roadsides',
#   'NA'],
#  ['Heliopsis helianthoides',
#   ' oxeye sunflower, oxeye',
#   'Asteraceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Herbaceous',
#   '1 - 5ft; ',
#   'pale yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'June -          September',
#   'NA',
#   'NA',
#   'fields, open woods, floodplains, thickets, stream banks',
#   'long bloom time'],
#  ['Hepatica nobilis var. obtusa',
#   ' round-lobed hepatica, liverleaf',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 2ft; ',
#   'white to lavender',
#   'Capsule;         ',
#   'Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'dry or rocky woods, dry upland slopes',
#   'NA'],
#  ['Heracleum maximum',
#   ' cow parsnip',
#   'Apiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '3.5 - 10ft; ',
#   'white to pink',
#   'NA',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'May -          August',
#   'NA',
#   'NA',
# ...
#   'deciduous conifer'],
#  ['Thalictrum dioicum',
#   ' early meadow rue',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'green to purple',
#   'Capsule;         ',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'April -          May',
#   'NA',
#   'NA',
#   'rich rocky woods, ravines, alluvial terraces',
#   'NA'],
#  ['Thalictrum pubescens',
#   ' tall meadow rue',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '1.5 - 9ft; ',
#   'white',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'June -          August',
#   'NA',
#   'NA',
#   'rich woods, low thickets, swamps, wet meadows, stream banks',
#   'foliage similar to columbines; clump-forming; delicate flowers; species very variable'],
#  ['Thalictrum thalictroides',
#   ' rue anemone, windflower',
#   'Ranunculaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'wooded banks and thickets',
#   'foliage similar to columbines'],
#  ['Thelypteris noveboracensis',
#   ' New York fern',
#   'Thelypteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Fern',
#   '1 - 2.5ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'forested wetlands, dry to damp woods and thickets',
#   'tolerates drought; easily transplanted; forms large colonies; spreads easily'],
#  ['Thelypteris palustris',
#   ' marsh fern',
#   'Thelypteridaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '2 - 3ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'swamps, bogs, wet fields or thickets, fresh tidal and nontidal marshes, wooded streambanks',
#   'spreads'],
#  ['Tiarella cordifolia',
#   ' foamflower, false miterwort, heartleaf foamflower',
#   'Saxifragaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'white',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'Yes',
#   'rich woods, moist rocky wooded slopes',
#   'attractive, long-blooming; creeping, clump-forming; many cultivars'],
#  ['Tradescantia virginiana',
#   " Virginia spiderwort, widow's tears",
#   'Commelinaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Herbaceous',
#   '1 - 3ft; ',
#   'deep blue-purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'NA',
#   'wooded slopes, shale outcrops, moist fields, roadsides',
#   'flowers showy'],
#  ['Tridens flavus',
#   ' redtop, purpletop',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, VA, WV',
#   'Grass/Grasslike',
#   '2 - 6.5ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'dry fields, roadsides, openings, borders of woods',
#   'NA'],
#  ['Trillium grandiflorum',
#   ' white trillium, large-flowered trillium',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1.5ft; ',
#   'white then pink',
#   'Berry;          black',
#   'Shade',
#   'Loamy',
#   'Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'moist woods',
#   'showy flowers; common, often in large colonies'],
#  ['Tripsacum dactyloides',
#   ' gama grass',
#   'Poaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Grass/Grasslike',
#   '6 - 10ft; ',
#   'NA',
#   'NA',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy',
#   'Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'swales, moist fields, borders of woods, shores',
#   'excellent forage grass; often grows wild near corn fields; can hybridize with corn'],
#  ['Ulmus americana',
#   ' American elm, white elm, soft elm',
#   'Ulmaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Tall Tree (Canopy)',
#   '75 - 100ft; Spread: 75 - 100ft',
#   'red brown',
#   'Winged;          tan brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'March -          April',
#   'bright yellow',
#   'NA',
#   'river bottoms, swamps, disturbed fields, road sides, cutover forests',
#   'Dutch elm disease caused decline; distinctive "vase" shape; favorite nesting site of Baltimore oriole'],
#  ['Uvularia perfoliata',
#   ' perfoliate bellwort, mealy bellwort',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 2ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist',
#   'April -          July',
#   'NA',
#   'NA',
#   'moist woods',
#   'rhizome can be cooked and eaten; young shoots maybe substituted for asparagus'],
#  ['Uvularia sessilifolia',
#   ' straw lily',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'May -          June',
#   'NA',
#   'Yes',
#   'dry to moist woodland',
#   'rhizomes may be cooked and eaten; young shoots may be substituted for asparagus'],
#  ['Vaccinium corymbosum',
#   ' highbush blueberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white or pink-tinged',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'April -          June',
#   'yellow to red',
#   'NA',
#   'forested wetlands, shrub swamps, bogs, upland woods; dry to wet woods, thickets, stream banks, rock outcroppings',
#   'edible berries commonly cultivated'],
#  ['Vaccinium macrocarpon',
#   ' cranberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain',
#   'DE, DC, MD, NY, PA, WV',
#   'Low Shrub',
#   '0.5 - 1ft; Spread: 3 - 3ft',
#   'white to pink',
#   'Berry;          red',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Wet',
#   'June -          July',
#   'dark green to purple to red',
#   'Yes',
#   'sphagnum bogs, cool wet swampy ground',
#   'low mat form, can spread indefinitely; edible cranberries'],
#  ['Vaccinium pallidum',
#   ' early lowbush blueberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, PA, VA, WV',
#   'Low Shrub',
#   '1.5 - 2ft; ',
#   'white, reddish',
#   'Berry;          blue',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'April -          May',
#   'NA',
#   'Yes',
#   'dry woods and barrens',
#   'sweet berries'],
#  ['Vaccinium stamineum',
#   ' deerberry',
#   'Ericaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'white or purple',
#   'Berry;          bluish black',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'red',
#   'NA',
#   'dry woods, openings, barrens; dry upland oak woods, floodplain forests, clearings and thickets, pine woods and barrens, rock outcroppings',
#   'berries edible but sour'],
#  ['Veratrum viride',
#   ' green false hellebore, white hellebore',
#   'Liliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '2 - 5ft; ',
#   'yellow-green',
#   'Capsule;         ',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'May -          July',
#   'NA',
#   'NA',
#   'swamps & wet woods',
#   'leaf edges will brown if soil dries and plant is in windy area; does best in cooler temps; slugs like the foliage'],
#  ['Verbena hastata',
#   " blue vervain, simpler's joy",
#   'Verbenaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '1.5 - 5ft; ',
#   'blue to purple',
#   'Nut/Nut-like;         ',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'June -          October',
#   'NA',
#   'NA',
#   'moist meadows, swamps floodplains, wet ditches, roadsides',
#   'bright flowers; herbal uses'],
#  ['Verbesina alternifolia',
#   ' wingstem, yellow ironweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, VA, WV',
#   'Herbaceous',
#   '3.5 - 8ft; ',
#   'yellow',
#   'Capsule;         ',
#   'Full Sun',
#   'NA',
#   'Moist',
#   'August -          October',
#   'NA',
#   'NA',
#   'moist wooded slopes and open woodlands, riverbanks, shaded lowlands, roadsides, fields',
#   'threatened in NY'],
#  ['Vernonia noveboracensis',
#   ' New York ironweed',
#   'Asteraceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Emergent Herbaceous (Can grow with roots in water), Herbaceous',
#   '3.5 - 8ft; ',
#   'purple',
#   'Capsule;         ',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'August -          October',
#   'NA',
#   'NA',
#   'stream banks, wet fields, fresh water marshes',
#   'brilliant flowers; tall upright form adds structure to garden; spreads'],
#  ['Viburnum acerifolium',
#   ' maple-leaved arrowwood',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Low Shrub',
#   '3 - 6ft; Spread: 3 - 6ft',
#   'creamy-white, pink',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist',
#   'June -          June',
#   'orange, red, purple',
#   'NA',
#   'floodplain forests, dry wooded slopes, mixed deciduous forests, talus slopes, rock outcrops, wooded ravines',
#   'dry, edible berries'],
#  ['Viburnum dentatum',
#   ' southern arrowwood',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Medium Shrub, Tall Shrub',
#   '10 - 15ft; Spread: 6 - 12ft',
#   'white',
#   'Berry;          blue to black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'reddish-purple',
#   'NA',
#   'swamps and wet woods, bogs, floodplain forests, stream banks; low, wet acid-sand habitats',
#   'stems very straight, nice structure in winter'],
#  ['Viburnum nudum',
#   ' naked witherod, possum-haw viburnum',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA',
#   'Medium Shrub',
#   '6.5 - 20ft; Spread: 12 - 20ft',
#   'white to cream',
#   'Berry;          red to blue, then black',
#   'Full Sun, Partial Sun, Shade',
#   'Loamy, Sandy',
#   'Moist, Wet',
#   'June -          July',
#   'red to purple',
#   'NA',
#   'wet woods, swamps, margins of vernal ponds, heath bogs, deep rich upland forests, creek bottoms, wet sandy woods',
#   'edible fruit but very acidic; shallow fibrous roots, transplants well'],
#  ['Viburnum nudum var. cassinoides',
#   ' witherod',
#   'Adoxaceae, Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'MD, PA',
#   'Medium Shrub',
#   '6 - 12ft; Spread: 6 - 12ft',
#   'creamy white',
#   'Berry;          pink to blue-black',
#   'Full Sun, Partial Sun',
#   'Loamy',
#   'Dry, Moist, Wet',
#   'May -          June',
#   'orange-red to purple',
#   'NA',
#   'swamps, bogs, moist woods, and barrens',
#   'handsome stature; multiple fruit colors at once'],
#  ['Viburnum prunifolium',
#   ' black haw',
#   'Caprifoliaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Small/Medium Tree (Understory), Tall Shrub',
#   '12 - 24ft; Spread: 8 - 12ft',
#   'white',
#   'Berry;          pink to bluish-black',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Dry, Moist, Wet',
#   'April -          May',
#   'reddish purple',
#   'NA',
#   'successional woods, thickets, old fields, and roadsides',
#   'fruits edible, used for preserves'],
#  ['Viola conspersa',
#   ' American dog violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'pale blue, violet',
#   'Capsule;          green',
#   'Full Sun, Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'April -          July',
#   'NA',
#   'Yes',
#   'moist woods, damp fields, swamps',
#   'delicate plant and flower; edible'],
#  ['Viola cucullata',
#   ' marsh blue violet, blue marsh violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, PA, VA, WV',
#   'Herbaceous',
#   'NA',
#   'pale purple',
#   'Capsule;          green',
#   'Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          July',
#   'NA',
#   'Yes',
#   'bogs, meadows, & swamps',
#   'stemless; self-sows; can become a nuisance'],
#  ['Viola pedata',
#   " bird's foot violet",
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, VA, WV',
#   'Herbaceous',
#   'NA',
#   'pale blue or w/ purple-black tips',
#   'Capsule;          green',
#   'Full Sun, Partial Sun',
#   'Loamy, Sandy',
#   'Dry, Moist',
#   'March -          June',
#   'NA',
#   'Yes',
#   'sandy or rocky barrens, dry forested slopes',
#   'stemless'],
#  ['Viola sororia',
#   ' common blue violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 0.5ft; ',
#   'dark blue, violet',
#   'Capsule;          green with purple',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy',
#   'Moist',
#   'March -          June',
#   'NA',
#   'NA',
#   'dry to moist woods, swamps, thickets',
#   'delicate plant and flower; edible; spreader; stemless'],
#  ['Viola striata',
#   ' striped cream violet, striped violet',
#   'Violaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, MD, NY, PA, VA, WV',
#   'Herbaceous',
#   '0.5 - 1ft; ',
#   'ivory w/ purple',
#   'Capsule;          green',
#   'Partial Sun',
#   'Loamy',
#   'Moist, Wet',
#   'April -          June',
#   'NA',
#   'NA',
#   'alluvial woods, alkaline swamps, moist fields',
#   'NA'],
#  ['Wisteria frutescens',
#   ' Atlantic wisteria, American wisteria',
#   'Fabaceae',
#   'Coastal Plain',
#   'DE, VA',
#   'Vine',
#   '20 - 20ft; ',
#   'lilac',
#   'Pod;          brown',
#   'Full Sun, Partial Sun',
#   'Clay, Loamy, Sandy',
#   'Moist, Wet',
#   'April -          August',
#   'NA',
#   'NA',
#   'borders of wooded swamps and wet woodlands, stream banks, moist or wet thickets',
#   'NA'],
#  ['Woodwardia areolata',
#   ' netted chain fern',
#   'Blechnaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '0.5 - 2ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'mostly acid bogs, swamps, or wet woods',
#   'spreads by creeping rhizome'],
#  ['Woodwardia virginica',
#   ' Virginia chain fern',
#   'Blechnaceae',
#   'Coastal Plain, Piedmont',
#   'DE, DC, MD, NY, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Fern',
#   '3 - 6ft; ',
#   'NA',
#   'NA',
#   'Partial Sun, Shade',
#   'NA',
#   'Moist, Wet',
#   'NA',
#   'NA',
#   'Yes',
#   'swampy places, wet woods',
#   'spreads by creeping rhizome'],
#  ['Yucca filamentosa',
#   " Adam's needle",
#   'Agavaceae',
#   'Coastal Plain',
#   'DE, DC, MD, VA',
#   'Herbaceous',
#   '2 - 2.5ft; ',
#   'white',
#   'NA',
#   'Full Sun',
#   'Loamy, Sandy',
#   'Dry',
#   'June -          September',
#   'NA',
#   'NA',
#   'coastal sand dunes; outcroppings on thin rocky soils',
#   'flower stalk can rise 5-15 feet above foliage'],
#  ['Zizania aquatica',
#   ' wild rice',
#   'Poaceae',
#   'Coastal Plain',
#   'DE, DC, MD, NY, VA',
#   'Emergent Herbaceous (Can grow with roots in water), Grass/Grasslike',
#   '6 - 10ft; ',
#   'NA',
#   'Achene (dry, flat seed);         ',
#   'Full Sun',
#   'Clay, Loamy, Sandy',
#   'Flooded, Moist, Wet',
#   'June -          September',
#   'NA',
#   'NA',
#   'fresh tidal and nontidal marshes, stream borders, shallow waters',
#   'annual; edible'],
#  ['Zizia aurea',
#   ' golden-alexanders',
#   'Apiaceae',
#   'Coastal Plain, Mountain, Piedmont',
#   'DE, DC, NY, PA, VA, WV',
#   'Herbaceous',
#   '1 - 2.5ft; ',
#   'yellow',
#   'NA',
#   'Full Sun, Partial Sun, Shade',
#   'Clay, Loamy, Sandy',
#   'Dry, Moist',
#   'April -          June',
#   'NA',
#   'NA',
#   'wooded bottomland, stream banks, moist meadows, floodplain',
#   'NA']]
